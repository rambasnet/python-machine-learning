# %% [markdown]
# # Intro to Pandas
# - [https://pandas.pydata.org/](https://pandas.pydata.org/)
# - a fast, powerful, flexible and easy to use open source data analysis and manipulation tool built on Python
#
# ## What kind of data does pandas handle?
#
# ### pandas data table representation
# ![img](images/Pandas-Table.svg)
# - to work with pandas package, must first import the package
# - to install/update pandas you can use either conda or pip
#
# ```bash
# conda install pandas
# pip install pandas
# ```

# %%
import pandas as pd
import numpy as np

# %%
print(f'pandas version: {pd.__version__}')
print(f'numpy version: {np.__version__}')
# Out:
# pandas version: 2.2.0
# numpy version: 1.26.4

# %% [markdown]
# ## Series
#
# - series is 1-d labeled array capable of holding any data type (integers, strings, float, Python objects, etc.)
# - the axis labels collectively referred to as the **index**
# - API to create Series:
# ```python
# s = pd.Series(data, index=index)
# ```
#
# - data can be:
#     - NumPy's **ndarray**
#     - Python dictionary
#     - a scalar value (e.g. 5)
#     - Python List
# - index is a list of axis labels
#     - index can be thought as row id or sample id
# - if data is an ndarray, index must be the same length as data
#     - if no index is passed, default index will be created `[0, ..., len(data)-1]`
# - each column in the DataFrame is a Series

# %%
s = pd.Series(np.random.randn(5))

# %%
s
# Out:
# 0   -1.050908
# 1    1.145567
# 2   -1.122552
# 3   -0.350206
# 4    0.794316
# dtype: float64

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s1 = pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'])

# %%
s1
# Out:
# a   -0.542334
# b    0.717278
# c   -0.258132
# d    0.307099
# e   -0.719742
# dtype: float64

# %%
s1.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
# from dict
d = {"b": 1, "a": 0, "c": 2}
s2 = pd.Series(d)

# %%
s2
# Out:
# b    1
# a    0
# c    2
# dtype: int64

# %%
# scalar value is repeated to match the length of index
s3 = pd.Series(5.0, index=["a", "b", "c", "d", "e"])

# %%
s3
# Out:
# a    5.0
# b    5.0
# c    5.0
# d    5.0
# e    5.0
# dtype: float64

# %%
# creating Series from Python List
s4 = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s4
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# ### Series is ndarray-like
# - Series acts very similar to a ndarray, and is a valid argument to most NumPy functions
# - slicing Series also slices the index

# %%
s1
# Out:
# a   -0.048182
# b    0.713255
# c    0.270073
# d   -0.450289
# e   -0.782588
# dtype: float64

# %%
s1[0]
# Out:
# -0.04818225722193457

# %%
s1[3:]
# Out:
# d   -0.450289
# e   -0.782588
# dtype: float64

# %%
# slice using condition
s1[s1 > s1.median()]
# Out:
# b    0.713255
# c    0.270073
# dtype: float64

# %%
# slice using indices
s1[[4, 3, 1]]
# Out:
# e   -0.782588
# d   -0.450289
# b    0.713255
# dtype: float64

# %%
# calculate the exponential (2*n) of each element n in the ndarray
# https://numpy.org/doc/stable/reference/generated/numpy.exp.html?highlight=exp#numpy.exp
np.exp2(s3)
# Out:
# a    32.0
# b    32.0
# c    32.0
# d    32.0
# e    32.0
# dtype: float64

# %%
s3.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### extract data array from Series
# - extract just data as array without index

# %%
s3.array
# Out:
# <PandasArray>
# [5.0, 5.0, 5.0, 5.0, 5.0]
# Length: 5, dtype: float64

# %% [markdown]
# ### convert series to ndarray

# %%
ndarr = s3.to_numpy()

# %%
ndarr
# Out:
# array([5., 5., 5., 5., 5.])

# %%
type(ndarr)
# Out:
# numpy.ndarray

# %%
ndarr.size
# Out:
# 5

# %%
ndarr.shape
# Out:
# (5,)

# %% [markdown]
# ### Series is dict-like
# - use index as the key to get the corresponding value

# %%
s1['a']
# Out:
# -0.04818225722193457

# %%
s3['e']
# Out:
# 5.0

# %%
s3['e'] = 15.0

# %%
s3
# Out:
# a     5.0
# b     5.0
# c     5.0
# d     5.0
# e    15.0
# dtype: float64

# %%
s3['g']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/ml/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/miniconda3/envs/ml/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/miniconda3/envs/ml/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'g'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/4f/1pkkv7h960j42p0ppgk9n4ywjr6t_b/T/ipykernel_40689/2681873957.py in <module>
# ----> 1 s3['g']
#
# ~/miniconda3/envs/ml/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~/miniconda3/envs/ml/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~/miniconda3/envs/ml/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'g'

# %%
# use get with default value if key is missing
s3.get('g', np.nan)
# Out:
# nan

# %% [markdown]
# ### Vectorized operations and label alignment with Series
# - very similar to NumPy ndarray

# %%
s3
# Out:
# a     5.0
# b     5.0
# c     5.0
# d     5.0
# e    15.0
# dtype: float64

# %%
s3+s3
# Out:
# a    10.0
# b    10.0
# c    10.0
# d    10.0
# e    30.0
# dtype: float64

# %%
s3-s3
# Out:
# a    0.0
# b    0.0
# c    0.0
# d    0.0
# e    0.0
# dtype: float64

# %%
s3*2
# Out:
# a    10.0
# b    10.0
# c    10.0
# d    10.0
# e    30.0
# dtype: float64

# %%
s3/5
# Out:
# a    1.0
# b    1.0
# c    1.0
# d    1.0
# e    3.0
# dtype: float64

# %%
# Series automatically aligns the data based on label
# if the label is not found in one Series or the other, the result will be marked as missing NaN
s3[1:] + s3[:-1]
# Out:
# a     NaN
# b    10.0
# c    10.0
# d    10.0
# e     NaN
# dtype: float64

# %% [markdown]
# ### Name attribute
# - Series can also have a **name** atribute

# %%
s4 = pd.Series(np.random.randn(5), name="Some Name")

# %%
s4.name
# Out:
# 'Some Name'

# %%
s4
# Out:
# 0    0.698834
# 1   -0.913744
# 2    0.496605
# 3    1.581900
# 4   -1.805908
# Name: Some Name, dtype: float64

# %%
# Series.rename creates a new Series with new name
s5 = s4.rename('New Name')

# %%
s5
# Out:
# 0    0.698834
# 1   -0.913744
# 2    0.496605
# 3    1.581900
# 4   -1.805908
# Name: New Name, dtype: float64

# %% [markdown]
# ## DataFrame
# - data table in pandas is called DataFrame
# - DataFrame is the primary data structure of pandas
# - Python dict can be used create DataFrame where keys will be used as column headers and the list of values as columns of the DataFrame
# - each column of DataFrame is called `Series`

# %%
aDict = {
    "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth"
    ],
    "Age": [22, 35, 58],
    "Sex": ["male", "male", "female"]
}

# %%
df = pd.DataFrame(aDict)

# %%
df
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
df2 = pd.DataFrame(
{
    "A": 1.0,
    "B": pd.Timestamp("20130102"),
    "C": pd.Series(1, index=list(range(4)), dtype="float32"),
    "D": np.array([3] * 4, dtype="int32"),
    "E": pd.Categorical(["test", "train", "test", "train"]),
    "F": "foo",
})

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# ### spreadsheet data
# - the above df can be represented in a spreadsheet software
# ![SpreadSheet](./images/01_table_spreadsheet.png)

# %%
df
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
# just work with the data in column - Age
# use dictionary syntax
df["Age"]
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
# access series/column as attribute
df.Age
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %% [markdown]
# ## DataFrame Complete Reference
# - complete reference: https://pandas.pydata.org/pandas-docs/stable/reference/frame.html
#
# ## DataFrame utility methods and attributes to review data
# - `df.columns` - return the column labels of the DataFrame
# - `df.index` - return the index (row labels/ids) of the DataFrame df object
# - `df.dtypes` - return Series with the data type of each column in the df object
# - `df.values` - return a **NumPy** representation of the DataFrame df object
# - `df.axes` - return a list representing the axes of the DataFrame, `[row labels]` and `[column labels]`
# - `df.shape` - return a tuple representing the dimensionality of the DataFrame df object
# - `df.size` - return an int representing the number of elements in the DataFrame df object
# - `df.info()` - print a concise summary of a DataFrame df object
# - `df.describe()` - generate descriptive statistics
# - `df.head(n)` - display the first n rows in the DataFarme df object; default n=5
# - `df.tail(n)` - display the last n rows in the DataFrame df object; default n=5

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Sex'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.values
# Out:
# array([['Braund, Mr. Owen Harris', 22, 'male'],
#        ['Allen, Mr. William Henry', 35, 'male'],
#        ['Bonnell, Miss. Elizabeth', 58, 'female']], dtype=object)

# %%
df.dtypes
# Out:
# Name    object
# Age      int64
# Sex     object
# dtype: object

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=3, step=1),
#  Index(['Name', 'Age', 'Sex'], dtype='object')]

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %%
# generate descriptive statistics
df.describe()
# Out:
#              Age
# count   3.000000
# mean   38.333333
# std    18.230012
# min    22.000000
# 25%    28.500000
# 50%    35.000000
# 75%    46.500000
# max    58.000000

# %%
# print first 2 rows
df.head(2)
# Out:
#                        Name  Age   Sex
# 0   Braund, Mr. Owen Harris   22  male
# 1  Allen, Mr. William Henry   35  male

# %%
# get individual stats for each Searies
df['Age'].max()
# Out:
# 58

# %%
# print last 2 rows
df.tail(2)
# Out:
#                        Name  Age     Sex
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %% [markdown]
# ## Read and write tabular data
#
# ![](./images/02_io_readwrite1.svg)
#
# - use pandas `.read_*(fileName)` to read data from various formats
# - Pandas raw data: [https://github.com/pandas-dev/pandas/tree/master/doc/data](https://github.com/pandas-dev/pandas/tree/master/doc/data)
# - read_csv - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html

# %%
# read CSV file directly from the Internet
iris_df = pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/iris.data')

# %%
iris_df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
iris_df.tail()
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica

# %%
# technical summary of DataFrame
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  150 non-null    float64
#  1   SepalWidth   150 non-null    float64
#  2   PetalLength  150 non-null    float64
#  3   PetalWidth   150 non-null    float64
#  4   Name         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# statistical summary of iris dataset
iris_df.describe()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %% [markdown]
# ### Titanic Dataset
#
# - https://github.com/pandas-dev/pandas/blob/master/doc/data/titanic.csv
# - https://www.openml.org/d/40945
#
# #### Column name description
#
# ```
# PassengerId: Id of every passenger.
#
# Survived: This feature have value 0 and 1. 0 for not survived and 1 for survived.
#
# Pclass: Passenger class: 3 classes: Class 1, Class 2 and Class 3.
#
# Name: Name of passenger.
#
# Sex: Gender of passenger.
#
# Age: Age of passenger.
#
# SibSp: Indication that passenger have siblings and spouse.
#
# Parch: Whether a passenger is alone or have family.
#
# Ticket: Ticket number of passenger.
#
# Fare: Indicating the fare.
#
# Cabin: The cabin of passenger.
#
# Embarked: The embarked category.
# ```

# %%
# let's read titanic.csv file as DataFrame
titanicDf = pd.read_csv('data/titanic.csv')

# %%
titanicDf
# notice the dataset already provides PassengerId as index column
# read_csv automatically adds the index column or row id
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# let's read the csv with PassengerId as index column (row_id)
titanicDf = pd.read_csv('data/titanic.csv', index_col="PassengerId")

# %%
# print first 8 rows
titanicDf.head(8)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# 6                0      0            330877   8.4583   NaN        Q
# 7                0      0             17463  51.8625   E46        S
# 8                3      1            349909  21.0750   NaN        S

# %%
titanicDf.shape
# Out:
# (891, 11)

# %%
titanicDf.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %% [markdown]
# ## Sort table rows
# - based on some column name
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html
#
# ```python
# DataFrame.sort_values(by='columnName', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', ignore_index=False, key=None)
# ```
#
# - returns the sorted DataFrame (NOT an inplace sort by default)

# %%
sortedTitanicDf = titanicDf.sort_values(by='Age')

# %%
sortedTitanicDf.head()
# Out:
#              Survived  Pclass                             Name     Sex   Age  \
# PassengerId
# 804                 1       3  Thomas, Master. Assad Alexander    male  0.42
# 756                 1       2        Hamalainen, Master. Viljo    male  0.67
# 645                 1       3           Baclini, Miss. Eugenie  female  0.75
# 470                 1       3    Baclini, Miss. Helene Barbara  female  0.75
# 79                  1       2    Caldwell, Master. Alden Gates    male  0.83
#
#              SibSp  Parch  Ticket     Fare Cabin Embarked
# PassengerId
# 804              0      1    2625   8.5167   NaN        C
# 756              1      1  250649  14.5000   NaN        S
# 645              2      1    2666  19.2583   NaN        C
# 470              2      1    2666  19.2583   NaN        C
# 79               0      2  248738  29.0000   NaN        S

# %%
# sorting by default returns sorted DF without sorting original DF in place
titanicDf.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
# sort using multiple columns and in descending order
titanicDf.sort_values(by=['Pclass', 'Age'], ascending=False).head()
# Out:
#              Survived  Pclass                       Name     Sex   Age  SibSp  \
# PassengerId
# 852                 0       3        Svensson, Mr. Johan    male  74.0      0
# 117                 0       3       Connors, Mr. Patrick    male  70.5      0
# 281                 0       3           Duane, Mr. Frank    male  65.0      0
# 484                 1       3     Turkula, Mrs. (Hedwig)  female  63.0      0
# 327                 0       3  Nysveen, Mr. Johan Hansen    male  61.0      0
#
#              Parch  Ticket    Fare Cabin Embarked
# PassengerId
# 852              0  347060  7.7750   NaN        S
# 117              0  370369  7.7500   NaN        Q
# 281              0  336439  7.7500   NaN        Q
# 484              0    4134  9.5875   NaN        S
# 327              0  345364  6.2375   NaN        S

# %% [markdown]
# ### Write the DataFrame as Excel file
#
# - install openpyxl library from Terminal; doesn't seem to work from notebook
#
# ```bash
# conda activate ml
# conda install -y openpyxl
# ```

# %%
! conda install -y openpyxl
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
sortedTitanicDf.to_excel('data/titanic_sorted_age.xlsx', sheet_name='passengers')

# %%
# technical summary of DataFrame
sortedTitanicDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 804 to 889
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# ## Select a subset of a DataFrame
#
# ### Select specific columns
# ![](./images/03_subset_columns.svg)

# %%
# copy just the Age column or Series
ages = titanicDf['Age']

# %%
type(ages)
# Out:
# pandas.core.series.Series

# %%
ages.shape
# Out:
# (891,)

# %%
# get age and sex columns
age_sex = titanicDf[['Age', 'Sex']]

# %%
type(age_sex)
# Out:
# pandas.core.frame.DataFrame

# %%
age_sex.head()
# Out:
#               Age     Sex
# PassengerId
# 1            22.0    male
# 2            38.0  female
# 3            26.0  female
# 4            35.0  female
# 5            35.0    male

# %%
age_sex.shape
# Out:
# (891, 2)

# %%
# boolen mask of passengers older than 35; returns True or False based on condition
titanicDf['Age'] > 35
# Out:
# PassengerId
# 1      False
# 2       True
# 3      False
# 4      False
# 5      False
#        ...
# 887    False
# 888    False
# 889    False
# 890    False
# 891    False
# Name: Age, Length: 891, dtype: bool

# %%
# DF of passengers older than 35
# passengers older than 35; returns True or False based on condition
titanicDf[titanicDf['Age'] > 35]
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 7                   0       1
# 12                  1       1
# 14                  0       3
# 16                  1       2
# ...               ...     ...
# 866                 1       2
# 872                 1       1
# 874                 0       3
# 880                 1       1
# 886                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 14                                 Andersson, Mr. Anders Johan    male  39.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# ...                                                        ...     ...   ...
# 866                                   Bystrom, Mrs. (Karolina)  female  42.0
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# 874                                Vander Cruyssen, Mr. Victor    male  47.0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 886                       Rice, Mrs. William (Margaret Norton)  female  39.0
#
#              SibSp  Parch    Ticket     Fare Cabin Embarked
# PassengerId
# 2                1      0  PC 17599  71.2833   C85        C
# 7                0      0     17463  51.8625   E46        S
# 12               0      0    113783  26.5500  C103        S
# 14               1      5    347082  31.2750   NaN        S
# 16               0      0    248706  16.0000   NaN        S
# ...            ...    ...       ...      ...   ...      ...
# 866              0      0    236852  13.0000   NaN        S
# 872              1      1     11751  52.5542   D35        S
# 874              0      0    345765   9.0000   NaN        S
# 880              0      1     11767  83.1583   C50        C
# 886              0      5    382652  29.1250   NaN        Q
#
# [217 rows x 11 columns]

# %% [markdown]
# ## Select specific rows and columns
# - create new DataFrame using the filtered rows and columns
#
# - two ways:
#
# ### df.iloc selections
# - use row ids and column ids
# ```python
# df.iloc[[row selection], [column selection]]
# ```
# - row selection can be:
#     - single row index values: `[100]`
#     - integer list of row indices: `[0, 2, 10]`
#     - slice of row indices: `[2:10]`
#
# - column selection can be:
#     - single column selection: `[10]`
#     - integer list of col indices: `[0, 3, 5]`
#     - slice of column indices: `[3:10]`
#
#
# ### df.loc selection
# - use row labels column labels
#
# ```python
# df.loc[[row selection], [column selection]]
# ```
# - row selection:
#     - single row label/index: `["john"]`
#     - list of row labels: `["john", "sarah"]`
#     - condition: `[data['age'] >= 35]`
# - column selection:
#     - single column name name: `['Age']`
#     - list of column names: `['Name, 'Age', 'Sex']`
#     - slice of column names: `['Name':'Age']`
#
#
# ### Select specific rows and all the columns
# ![](images/03_subset_rows.svg)

# %%
# Create new DataFrame based on the criteria
# similar to using where clause in SQL
passengers = titanicDf[titanicDf['Age']>35]

# %%
passengers.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 7                   0       1
# 12                  1       1
# 14                  0       3
# 16                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 14                                 Andersson, Mr. Anders Johan    male  39.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
#
#              SibSp  Parch    Ticket     Fare Cabin Embarked
# PassengerId
# 2                1      0  PC 17599  71.2833   C85        C
# 7                0      0     17463  51.8625   E46        S
# 12               0      0    113783  26.5500  C103        S
# 14               1      5    347082  31.2750   NaN        S
# 16               0      0    248706  16.0000   NaN        S

# %%
passengers.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  217.000000  217.000000  217.000000  217.000000  217.000000  217.000000
# mean     0.382488    1.811060   46.979263    0.345622    0.465438   43.966821
# std      0.487119    0.858653    9.188272    0.522983    1.075809   56.083306
# min      0.000000    1.000000   36.000000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   40.000000    0.000000    0.000000   12.525000
# 50%      0.000000    2.000000   45.000000    0.000000    0.000000   26.387500
# 75%      1.000000    3.000000   52.000000    1.000000    0.000000   55.900000
# max      1.000000    3.000000   80.000000    2.000000    6.000000  512.329200

# %%
# slect all passengers who survived - rows with Survived column = 1
survived = titanicDf[titanicDf['Survived'] == 1]

# %%
survived
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 9                   1       3
# 10                  1       2
# ...               ...     ...
# 876                 1       3
# 880                 1       1
# 881                 1       2
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# ...                                                        ...     ...   ...
# 876                           Najib, Miss. Adele Kiamie "Jane"  female  15.0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 881               Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 9                0      2            347742  11.1333   NaN        S
# 10               1      0            237736  30.0708   NaN        C
# ...            ...    ...               ...      ...   ...      ...
# 876              0      0              2667   7.2250   NaN        C
# 880              0      1             11767  83.1583   C50        C
# 881              0      1            230433  26.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 890              0      0            111369  30.0000  C148        C
#
# [342 rows x 11 columns]

# %%
# another example of selection
class_23 = titanicDf[titanicDf['Pclass'].isin([2, 3])]

# %%
class_23.head()
# Out:
#              Survived  Pclass                            Name     Sex   Age  \
# PassengerId
# 1                   0       3         Braund, Mr. Owen Harris    male  22.0
# 3                   1       3          Heikkinen, Miss. Laina  female  26.0
# 5                   0       3        Allen, Mr. William Henry    male  35.0
# 6                   0       3                Moran, Mr. James    male   NaN
# 8                   0       3  Palsson, Master. Gosta Leonard    male   2.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 5                0      0            373450   8.0500   NaN        S
# 6                0      0            330877   8.4583   NaN        Q
# 8                3      1            349909  21.0750   NaN        S

# %%
# select data where age is known
age_no_na = titanicDf[titanicDf['Age'].notna()]

# %%
age_no_na.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
age_no_na.shape
# Out:
# (714, 11)

# %%
# select rows 10-25 and columns 3-5
titanicDf.iloc[9:25, 2:5]
# Out:
#                                                           Name     Sex   Age
# PassengerId
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 13                              Saundercock, Mr. William Henry    male  20.0
# 14                                 Andersson, Mr. Anders Johan    male  39.0
# 15                        Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 17                                        Rice, Master. Eugene    male   2.0
# 18                                Williams, Mr. Charles Eugene    male   NaN
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0
# 20                                     Masselmani, Mrs. Fatima  female   NaN
# 21                                        Fynney, Mr. Joseph J    male  35.0
# 22                                       Beesley, Mr. Lawrence    male  34.0
# 23                                 McGowan, Miss. Anna "Annie"  female  15.0
# 24                                Sloper, Mr. William Thompson    male  28.0
# 25                               Palsson, Miss. Torborg Danira  female   8.0

# %%
# select rows based on row_ids or PassengerId
titanicDf.loc[[1, 3]]
# Out:
#              Survived  Pclass                     Name     Sex   Age  SibSp  \
# PassengerId
# 1                   0       3  Braund, Mr. Owen Harris    male  22.0      1
# 3                   1       3   Heikkinen, Miss. Laina  female  26.0      0
#
#              Parch            Ticket   Fare Cabin Embarked
# PassengerId
# 1                0         A/5 21171  7.250   NaN        S
# 3                0  STON/O2. 3101282  7.925   NaN        S

# %%
# slect rows based on row_ids and columns based on column ids
titanicDf.loc[[1, 3], ['Age', 'Name']]
# Out:
#               Age                     Name
# PassengerId
# 1            22.0  Braund, Mr. Owen Harris
# 3            26.0   Heikkinen, Miss. Laina

# %%
adult_names = titanicDf.loc[titanicDf['Age']>=18, ['Name']]

# %%
adult_names.head()
# Out:
#                                                           Name
# PassengerId
# 1                                      Braund, Mr. Owen Harris
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                       Heikkinen, Miss. Laina
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                     Allen, Mr. William Henry

# %%
# select passengers names older than 35 years
# NOTE: loc selects based on row or column names not id
adult_age_names = titanicDf.loc[titanicDf['Age'] > 35, ['Age', 'Name']]

# %%
adult_age_names.head()
# Out:
#               Age                                               Name
# PassengerId
# 2            38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 7            54.0                            McCarthy, Mr. Timothy J
# 12           58.0                           Bonnell, Miss. Elizabeth
# 14           39.0                        Andersson, Mr. Anders Johan
# 16           55.0                   Hewlett, Mrs. (Mary D Kingcome)

# %%
# TODO: select Age and Name of all the minor passengers with age less than 18

# %% [markdown]
# ## Updating selected fields with iloc and loc
# - update first 3 rows' Name column to "anonymous"
# - `iloc` uses 0-based indices for rows and columns

# %%
# Note: PassengerId is row index not part of column
titanicDf.iloc[0:3, 2] = 'anonymous'

# %%
titanicDf.head()
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                                     anonymous
# 2                   1       1                                     anonymous
# 3                   1       3                                     anonymous
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500   NaN
# 2            female  38.0      1      0          PC 17599  71.2833   C85
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 4            female  35.0      1      0            113803  53.1000  C123
# 5              male  35.0      0      0            373450   8.0500   NaN
#
#             Embarked
# PassengerId
# 1                  S
# 2                  C
# 3                  S
# 4                  S
# 5                  S

# %%
# update Name of all the children's age < 13 to anonymous
titanicDf.loc[titanicDf['Age'] < 13, ['Name']] = 'anonymous'

# %%
# let's select and print just the Name column
titanicDf.loc[titanicDf['Age'] < 13, ['Name']]
# Out:
#                   Name
# PassengerId
# 8            anonymous
# 11           anonymous
# 17           anonymous
# 25           anonymous
# 44           anonymous
# ...                ...
# 828          anonymous
# 832          anonymous
# 851          anonymous
# 853          anonymous
# 870          anonymous
#
# [69 rows x 1 columns]

# %% [markdown]
# ## Creating new columns derived from existing columns
#
# ![](./images/05_newcolumn_1.svg)
# - similar to adding just another Series with the column name as the key in DataFrame dictionary
# - the calculation of the values is done **element_wise**
# - remember, broadcast method?
#     - you don't need to use loop to iterate each of the rows
# - syntax:
#
# ```python
# df['new_column_name'] = pd.Series()
# ```

# %% [markdown]
# ## Open Air Quality Data
# - OpenAQ Data - [https://openaq.org/#/](https://openaq.org/#/)
# - http://dhhagan.github.io/py-openaq/tutorial/api.html#openaq-api
# https://py-openaq.readthedocs.io/en/latest/
#
# ```bash
# pip install py-openaq
# ```
#
# ### Let's use air quality data provided by OpenAQ API

# %%
! pip install py-openaq
# Out:
# Collecting py-openaq
#   Using cached py-openaq-1.1.0.tar.gz (7.9 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: py-openaq
#   Building wheel for py-openaq (setup.py) ... done
#   Created wheel for py-openaq: filename=py_openaq-1.1.0-py3-none-any.whl size=9037 sha256=32ed2edd58fdd7095eee7abfc206dfcdd011f341cb44c19985440065ef607113
#   Stored in directory: /Users/rbasnet/Library/Caches/pip/wheels/b0/87/d2/6824c8ea805b5ed5de4993b7d728b490d98d6b51abc54ddaf1
# Successfully built py-openaq
# Installing collected packages: py-openaq
# Successfully installed py-openaq-1.1.0

# %%
import openaq
import json

# %%
api = openaq.OpenAQ()

# %%
# get the cities data
# resp = api.cities(df=True, limit=10000) # doesn't work anymore!
data = api.cities(limit=1000) # just get raw data first and convert it into DataFrame

# %%
# Tple of results; 'result' in index 1 has the list of records we need!
data
# Out:
# (200,
#  {'meta': {'name': 'openaq-api',
#    'license': '',
#    'website': '/',
#    'page': 1,
#    'limit': 1000,
#    'found': 2475,
#    'pages': 3},
#   'results': [{'country': 'TW',
#     'city': ' ',
#     'count': 4863951,
#     'locations': 66},
#    {'country': 'JP', 'city': ' ', 'count': 24985118, 'locations': 1530},
#    {'country': 'CN', 'city': ' ', 'count': 142407, 'locations': 1},
#    {'country': 'US', 'city': '007', 'count': 20445, 'locations': 4},
#    {'country': 'US', 'city': '015', 'count': 1025, 'locations': 1},
#    {'country': 'US', 'city': '037', 'count': 13693, 'locations': 1},
#    {'country': 'US', 'city': '039', 'count': 6662, 'locations': 2},
#    {'country': 'US', 'city': '047', 'count': 21484, 'locations': 4},
#    {'country': 'US', 'city': '057', 'count': 2721, 'locations': 1},
#    {'country': 'US', 'city': '059', 'count': 3134, 'locations': 1},
#    {'country': 'US', 'city': '069', 'count': 2227, 'locations': 1},
#    {'country': 'IT', 'city': 'A2A', 'count': 8568, 'locations': 5},
#    {'country': 'US', 'city': 'Aberdeen', 'count': 52367, 'locations': 1},
#    {'country': 'CI', 'city': 'Abidjan', 'count': 28046, 'locations': 1},
#    {'country': 'AE', 'city': 'Abu Al Abyad', 'count': 18872, 'locations': 1},
#    {'country': 'AE', 'city': 'Abu Dhabi', 'count': 215891, 'locations': 9},
#    {'country': 'GH', 'city': 'Accra', 'count': 26865, 'locations': 1},
#    {'country': 'ES', 'city': 'A Coruña', 'count': 924408, 'locations': 15},
#    {'country': 'MX', 'city': 'Actopan', 'count': 4171, 'locations': 1},
#    {'country': 'US', 'city': 'ADA', 'count': 39214, 'locations': 1},
#    {'country': 'US', 'city': 'ADAIR', 'count': 217554, 'locations': 1},
#    {'country': 'US', 'city': 'ADAMS', 'count': 77365, 'locations': 2},
#    {'country': 'TR', 'city': 'Adana', 'count': 287572, 'locations': 8},
#    {'country': 'ET', 'city': 'Addis Ababa', 'count': 37262, 'locations': 1},
#    {'country': 'AU', 'city': 'Adelaide', 'count': 39466, 'locations': 2},
#    {'country': 'TR', 'city': 'Adıyaman', 'count': 8432, 'locations': 1},
#    {'country': 'US', 'city': 'Adrian', 'count': 85594, 'locations': 1},
#    {'country': 'TR', 'city': 'Afyonkarahisar', 'count': 34923, 'locations': 3},
#    {'country': 'TR', 'city': 'Ağrı', 'count': 121633, 'locations': 3},
#    {'country': 'MX', 'city': 'Aguascalientes', 'count': 80652, 'locations': 4},
#    {'country': 'MX', 'city': 'AGUASCALIENTES', 'count': 4073, 'locations': 2},
#    {'country': 'ES', 'city': 'Agullana', 'count': 27142, 'locations': 1},
#    {'country': 'US', 'city': 'AIR', 'count': 5971, 'locations': 13},
#    {'country': 'FR', 'city': 'AIR BREIZH', 'count': 144162, 'locations': 13},
#    {'country': 'FR', 'city': 'AIRPARIF', 'count': 3891902, 'locations': 46},
#    {'country': 'FR',
#     'city': 'AIR PAYS DE LA LOIRE',
#     'count': 2150963,
#     'locations': 31},
#    {'country': 'DE',
#     'city': 'Air Quality Luxembourg',
#     'count': 198403,
#     'locations': 1},
#    {'country': 'LU',
#     'city': 'Air Quality Luxembourg',
#     'count': 817286,
#     'locations': 8},
#    {'country': 'LV',
#     'city': 'Air Quality Monitoring Network',
#     'count': 93343,
#     'locations': 6},
#    {'country': 'HU', 'city': 'Ajka', 'count': 22410, 'locations': 1},
#    {'country': 'US', 'city': 'Akron', 'count': 148663, 'locations': 2},
#    {'country': 'TR', 'city': 'Aksaray', 'count': 20578, 'locations': 1},
#    {'country': 'IS', 'city': 'Akureyri', 'count': 59243, 'locations': 1},
#    {'country': 'AE', 'city': 'Al Ain', 'count': 117949, 'locations': 6},
#    {'country': 'US', 'city': 'ALAMEDA', 'count': 151361, 'locations': 1},
#    {'country': 'US', 'city': 'ALAMOSA', 'count': 401, 'locations': 1},
#    {'country': 'RO', 'city': 'Alba', 'count': 55557, 'locations': 2},
#    {'country': 'US', 'city': 'Albany', 'count': 39429, 'locations': 1},
#    {'country': 'US', 'city': 'Albany-Lebanon', 'count': 95341, 'locations': 2},
#    {'country': 'US',
#     'city': 'Albany-Schenectady-Troy',
#     'count': 117943,
#     'locations': 3},
#    {'country': 'CA', 'city': 'ALBERTA', 'count': 1921878, 'locations': 31},
#    {'country': 'US', 'city': 'Albuquerque', 'count': 902107, 'locations': 7},
#    {'country': 'ES', 'city': 'Alcanar', 'count': 25472, 'locations': 1},
#    {'country': 'NO', 'city': 'Ålesund', 'count': 128666, 'locations': 2},
#    {'country': 'US', 'city': 'ALEXANDER', 'count': 54472, 'locations': 1},
#    {'country': 'ZA', 'city': 'Alfred Nzo', 'count': 43483, 'locations': 5},
#    {'country': 'US', 'city': 'Allegan', 'count': 55014, 'locations': 1},
#    {'country': 'US',
#     'city': 'Allentown-Bethlehem-Easton',
#     'count': 187351,
#     'locations': 2},
#    {'country': 'ES', 'city': 'Almería', 'count': 121914, 'locations': 1},
#    {'country': 'MX',
#     'city': 'Almoloya de Juárez',
#     'count': 23837,
#     'locations': 1},
#    {'country': 'FR',
#     'city': 'Alpes-de-Haute-Provence',
#     'count': 253613,
#     'locations': 2},
#    {'country': 'FR',
#     'city': 'Alpes-Maritimes',
#     'count': 356476,
#     'locations': 5},
#    {'country': 'AE',
#     'city': 'Al Ruways Industrial City',
#     'count': 24225,
#     'locations': 1},
#    {'country': 'CL', 'city': 'Alto Hospicio', 'count': 6182, 'locations': 1},
#    {'country': 'AU', 'city': 'Altona North', 'count': 36497, 'locations': 1},
#    {'country': 'US', 'city': 'Altoona', 'count': 96162, 'locations': 1},
#    {'country': 'MX', 'city': 'Álvaro Obregón', 'count': 40162, 'locations': 1},
#    {'country': 'US', 'city': 'AMADOR', 'count': 30566, 'locations': 1},
#    {'country': 'US', 'city': 'Amarillo', 'count': 59024, 'locations': 2},
#    {'country': 'TR', 'city': 'Amasya', 'count': 193554, 'locations': 4},
#    {'country': 'BR', 'city': 'Americana', 'count': 34528, 'locations': 1},
#    {'country': 'US', 'city': 'Americus', 'count': 35614, 'locations': 1},
#    {'country': 'JO', 'city': 'Amman', 'count': 41919, 'locations': 1},
#    {'country': 'TH', 'city': 'Amnat Charoen', 'count': 5432, 'locations': 1},
#    {'country': 'ES', 'city': 'Amposta', 'count': 62660, 'locations': 1},
#    {'country': 'NL', 'city': 'Amsterdam', 'count': 1644258, 'locations': 13},
#    {'country': 'SK',
#     'city': 'Amt der Burgenländischen Landesregierung',
#     'count': 1794,
#     'locations': 1},
#    {'country': 'AT',
#     'city': 'Amt der Burgenländischen Landesregierung',
#     'count': 3170,
#     'locations': 2},
#    {'country': 'AT',
#     'city': 'Amt der Kärntner Landesregierung',
#     'count': 476195,
#     'locations': 15},
#    {'country': 'AT',
#     'city': 'Amt der Niederösterreichischen Landesregierung',
#     'count': 891005,
#     'locations': 38},
#    {'country': 'AT',
#     'city': 'Amt der Oberösterreichischen Landesregierung',
#     'count': 548009,
#     'locations': 15},
#    {'country': 'AT',
#     'city': 'Amt der Salzburger Landesregierung',
#     'count': 282630,
#     'locations': 13},
#    {'country': 'AT',
#     'city': 'Amt der Steiermärkischen Landesregierung',
#     'count': 1906020,
#     'locations': 36},
#    {'country': 'SI',
#     'city': 'Amt der Steiermärkischen Landesregierung',
#     'count': 11599,
#     'locations': 1},
#    {'country': 'AT',
#     'city': 'Amt der Tiroler Landesregierung',
#     'count': 940356,
#     'locations': 19},
#    {'country': 'US', 'city': 'Anchorage', 'count': 202193, 'locations': 3},
#    {'country': 'CL', 'city': 'Andacollo', 'count': 101648, 'locations': 3},
#    {'country': 'US', 'city': 'Anderson', 'count': 72045, 'locations': 2},
#    {'country': 'US', 'city': 'ANDERSON', 'count': 18484, 'locations': 1},
#    {'country': 'DE',
#     'city': 'Andreas Hainsch',
#     'count': 1636284,
#     'locations': 26},
#    {'country': 'US', 'city': 'ANDREW', 'count': 33962, 'locations': 1},
#    {'country': 'TR', 'city': 'Ankara', 'count': 444619, 'locations': 20},
#    {'country': 'US', 'city': 'Ann Arbor', 'count': 121879, 'locations': 2},
#    {'country': 'DE',
#     'city': 'Anne Merike Fiedler',
#     'count': 509801,
#     'locations': 12},
#    {'country': 'TR', 'city': 'Antalya', 'count': 116320, 'locations': 8},
#    {'country': 'CL', 'city': 'Antofagasta', 'count': 136526, 'locations': 1},
#    {'country': 'BE', 'city': 'Antwerpen', 'count': 68483, 'locations': 2},
#    {'country': 'IT',
#     'city': 'Aosta Valley Air Quality Network',
#     'count': 5411,
#     'locations': 5},
#    {'country': 'MX', 'city': 'Apizaco', 'count': 38748, 'locations': 1},
#    {'country': 'MX', 'city': 'Apodaca', 'count': 55506, 'locations': 1},
#    {'country': 'US', 'city': 'Appleton', 'count': 72674, 'locations': 1},
#    {'country': 'ES', 'city': 'Araba/Álava', 'count': 487833, 'locations': 5},
#    {'country': 'BR', 'city': 'Araçatuba', 'count': 30048, 'locations': 1},
#    {'country': 'RO', 'city': 'Arad', 'count': 114625, 'locations': 3},
#    {'country': 'RO', 'city': 'Arad-RNMCA', 'count': 3869, 'locations': 5},
#    {'country': 'US', 'city': 'ARAPAHOE', 'count': 44757, 'locations': 1},
#    {'country': 'BR', 'city': 'Araraquara', 'count': 39681, 'locations': 1},
#    {'country': 'US', 'city': 'ARCHULETA', 'count': 88649, 'locations': 2},
#    {'country': 'TR', 'city': 'Ardahan', 'count': 16801, 'locations': 1},
#    {'country': 'US', 'city': 'Ardmore', 'count': 129060, 'locations': 2},
#    {'country': 'RO', 'city': 'Argeş', 'count': 112132, 'locations': 3},
#    {'country': 'RO', 'city': 'Arges-RNMCA', 'count': 44136, 'locations': 5},
#    {'country': 'CL', 'city': 'Arica', 'count': 31492, 'locations': 1},
#    {'country': 'TT', 'city': 'Arima', 'count': 5821, 'locations': 1},
#    {'country': 'US', 'city': 'Arkadelphia', 'count': 35412, 'locations': 1},
#    {'country': 'GB', 'city': 'Armagh', 'count': 9862, 'locations': 1},
#    {'country': 'US', 'city': 'AROOSTOOK', 'count': 342463, 'locations': 3},
#    {'country': 'CA', 'city': 'AROOSTOOK', 'count': 59430, 'locations': 1},
#    {'country': 'IT', 'city': 'ARPA MOLISE', 'count': 22404, 'locations': 3},
#    {'country': 'TR', 'city': 'Artvin', 'count': 69220, 'locations': 2},
#    {'country': 'NZ', 'city': 'Ashburton', 'count': 2653, 'locations': 1},
#    {'country': 'US', 'city': 'Asheville', 'count': 117904, 'locations': 4},
#    {'country': 'TM', 'city': 'Ashgabat', 'count': 30791, 'locations': 1},
#    {'country': 'US', 'city': 'ASHLAND', 'count': 75389, 'locations': 1},
#    {'country': 'US', 'city': 'Ashtabula', 'count': 72183, 'locations': 1},
#    {'country': 'US', 'city': 'ASOTIN', 'count': 52758, 'locations': 1},
#    {'country': 'GB', 'city': 'Aston Hill', 'count': 109063, 'locations': 1},
#    {'country': 'ES', 'city': 'Asturias', 'count': 251718, 'locations': 3},
#    {'country': 'US', 'city': 'Athens', 'count': 42510, 'locations': 1},
#    {'country': 'US', 'city': 'ATHENS', 'count': 2256, 'locations': 1},
#    {'country': 'US',
#     'city': 'Athens-Clarke County',
#     'count': 99501,
#     'locations': 1},
#    {'country': 'MX', 'city': 'Atitalaquia', 'count': 62875, 'locations': 1},
#    {'country': 'US',
#     'city': 'Atlanta-Sandy Springs-Marietta',
#     'count': 623216,
#     'locations': 11},
#    {'country': 'US', 'city': 'Atlantic City', 'count': 138714, 'locations': 1},
#    {'country': 'MX', 'city': 'Atlixco', 'count': 3565, 'locations': 1},
#    {'country': 'FR',
#     'city': 'ATMO AUVERGNE-RH��NE-ALPES',
#     'count': 965,
#     'locations': 1},
#    {'country': 'FR',
#     'city': 'ATMO AUVERGNE-RHÔNE-ALPES',
#     'count': 6409327,
#     'locations': 66},
#    {'country': 'IT',
#     'city': 'ATMO AUVERGNE-RHÔNE-ALPES',
#     'count': 209683,
#     'locations': 2},
#    {'country': 'CH',
#     'city': 'ATMO BOURGOGNE-FRANCHE-COMTE',
#     'count': 113481,
#     'locations': 2},
#    {'country': 'FR',
#     'city': 'ATMO BOURGOGNE-FRANCHE-COMTE',
#     'count': 1241249,
#     'locations': 24},
#    {'country': 'DE',
#     'city': 'ATMO GRAND EST',
#     'count': 357380,
#     'locations': 4},
#    {'country': 'CH', 'city': 'ATMO GRAND EST', 'count': 99101, 'locations': 1},
#    {'country': 'FR',
#     'city': 'ATMO GRAND EST',
#     'count': 4498992,
#     'locations': 52},
#    {'country': 'FR', 'city': 'ATMO GUYANE', 'count': 230056, 'locations': 4},
#    {'country': 'FR',
#     'city': 'ATMO HAUTS DE FRANCE',
#     'count': 3215522,
#     'locations': 38},
#    {'country': 'BE',
#     'city': 'ATMO HAUTS DE FRANCE',
#     'count': 120648,
#     'locations': 1},
#    {'country': 'FR',
#     'city': 'ATMO NORMANDIE',
#     'count': 2512368,
#     'locations': 37},
#    {'country': 'FR',
#     'city': 'ATMO NOUVELLE-AQUITAINE',
#     'count': 1082556,
#     'locations': 42},
#    {'country': 'FR',
#     'city': 'ATMO OCCITANIE',
#     'count': 770318,
#     'locations': 38},
#    {'country': 'FR', 'city': 'ATMO SUD', 'count': 799851, 'locations': 44},
#    {'country': 'MX',
#     'city': 'Atotonilco de Tula',
#     'count': 63681,
#     'locations': 1},
#    {'country': 'GB', 'city': 'Auchencorth', 'count': 166049, 'locations': 1},
#    {'country': 'US',
#     'city': 'Augusta-Richmond County',
#     'count': 161337,
#     'locations': 4},
#    {'country': 'US',
#     'city': 'Augusta-Waterville',
#     'count': 22072,
#     'locations': 2},
#    {'country': 'PL', 'city': 'Augustów', 'count': 121852, 'locations': 2},
#    {'country': 'US',
#     'city': 'Austin-Round Rock',
#     'count': 216000,
#     'locations': 12},
#    {'country': 'PT', 'city': 'Aveiro', 'count': 196129, 'locations': 1},
#    {'country': 'US', 'city': 'AVERY', 'count': 18506, 'locations': 1},
#    {'country': 'TR', 'city': 'Aydın', 'count': 74022, 'locations': 9},
#    {'country': 'CL', 'city': 'Aysén', 'count': 40052, 'locations': 1},
#    {'country': 'ES', 'city': 'Ayto Madrid', 'count': 1727235, 'locations': 24},
#    {'country': 'ES', 'city': 'Ayto Zaragoza', 'count': 779223, 'locations': 8},
#    {'country': 'MX', 'city': 'Azcapotzalco', 'count': 36801, 'locations': 1},
#    {'country': 'RO', 'city': 'Bacău', 'count': 87508, 'locations': 3},
#    {'country': 'RO', 'city': 'Bacau-RNMCA', 'count': 1489, 'locations': 3},
#    {'country': 'ES', 'city': 'Badajoz', 'count': 88242, 'locations': 1},
#    {'country': 'ES', 'city': 'Badalona', 'count': 85841, 'locations': 1},
#    {'country': 'NL', 'city': 'Badhoevedorp', 'count': 211131, 'locations': 1},
#    {'country': 'NO', 'city': 'Bærum', 'count': 195572, 'locations': 3},
#    {'country': 'IQ', 'city': 'Baghdad', 'count': 34301, 'locations': 1},
#    {'country': 'US', 'city': 'BAKER', 'count': 46963, 'locations': 1},
#    {'country': 'US', 'city': 'Bakersfield', 'count': 478908, 'locations': 10},
#    {'country': 'TR', 'city': 'Balıkesir', 'count': 93328, 'locations': 4},
#    {'country': 'NL', 'city': 'Balk', 'count': 163646, 'locations': 1},
#    {'country': 'GB', 'city': 'Ballymena', 'count': 86162, 'locations': 1},
#    {'country': 'US', 'city': 'BALTIMORE', 'count': 52216, 'locations': 1},
#    {'country': 'US',
#     'city': 'BALTIMORE (CITY)',
#     'count': 38035,
#     'locations': 1},
#    {'country': 'US',
#     'city': 'Baltimore-Towson',
#     'count': 505872,
#     'locations': 6},
#    {'country': 'ML', 'city': 'Bamako', 'count': 23787, 'locations': 1},
#    {'country': 'GB', 'city': 'Banbridge', 'count': 40442, 'locations': 1},
#    {'country': 'ID', 'city': 'Bandung', 'count': 5133, 'locations': 1},
#    {'country': 'TH', 'city': 'Bangkok', 'count': 1946904, 'locations': 83},
#    {'country': 'US', 'city': 'Bangor', 'count': 32722, 'locations': 1},
#    {'country': 'US', 'city': 'BANNOCK', 'count': 63129, 'locations': 1},
#    {'country': 'SK',
#     'city': 'Banskobystrický kraj',
#     'count': 550766,
#     'locations': 4},
#    {'country': 'ME', 'city': 'Bar', 'count': 33538, 'locations': 1},
#    {'country': 'US', 'city': 'Baraboo', 'count': 118018, 'locations': 1},
#    {'country': 'ES',
#     'city': 'Barberà del Vallès',
#     'count': 32975,
#     'locations': 1},
#    {'country': 'CO', 'city': 'Barbosa', 'count': 71790, 'locations': 2},
#    {'country': 'ES', 'city': 'Barcelona', 'count': 277512, 'locations': 4},
#    {'country': 'IT', 'city': 'Bari', 'count': 213233, 'locations': 3},
#    {'country': 'GB',
#     'city': 'Barking and Dagenham',
#     'count': 69433,
#     'locations': 2},
#    {'country': 'GB', 'city': 'Barnsley', 'count': 175950, 'locations': 1},
#    {'country': 'US',
#     'city': 'Barnstable Town',
#     'count': 38888,
#     'locations': 1},
#    {'country': 'GB', 'city': 'Barnstaple', 'count': 96031, 'locations': 1},
#    {'country': 'NL', 'city': 'Barsbeek', 'count': 163649, 'locations': 1},
#    {'country': 'TR', 'city': 'Bartın', 'count': 25751, 'locations': 1},
#    {'country': 'TR', 'city': 'Batman', 'count': 8241, 'locations': 1},
#    {'country': 'US', 'city': 'Baton Rouge', 'count': 492593, 'locations': 9},
#    {'country': 'BR', 'city': 'Bauru', 'count': 46, 'locations': 1},
#    {'country': 'TR', 'city': 'Bayburt', 'count': 10189, 'locations': 1},
#    {'country': 'US', 'city': 'Bay City', 'count': 52591, 'locations': 1},
#    {'country': 'DE', 'city': 'Bayern', 'count': 117988, 'locations': 2},
#    {'country': 'US', 'city': 'BEAUFORT', 'count': 49237, 'locations': 1},
#    {'country': 'US',
#     'city': 'Beaumont-Port Arthur',
#     'count': 368109,
#     'locations': 10},
#    {'country': 'US', 'city': 'BEAVER', 'count': 13511, 'locations': 1},
#    {'country': 'US', 'city': 'BEAVERHEAD', 'count': 5578, 'locations': 1},
#    {'country': 'US', 'city': 'BECKER', 'count': 89942, 'locations': 1},
#    {'country': 'CH', 'city': 'Beide Basel', 'count': 113592, 'locations': 1},
#    {'country': 'CN', 'city': 'Beijing', 'count': 82917, 'locations': 2},
#    {'country': 'HU', 'city': 'Békéscsaba', 'count': 14887, 'locations': 1},
#    {'country': 'GB', 'city': 'Belfast', 'count': 376448, 'locations': 2},
#    {'country': 'US', 'city': 'Bellingham', 'count': 77446, 'locations': 2},
#    {'country': 'CO', 'city': 'Bello', 'count': 36068, 'locations': 1},
#    {'country': 'US', 'city': 'BELMONT', 'count': 136083, 'locations': 1},
#    {'country': 'PL', 'city': 'Belsk Duży', 'count': 106169, 'locations': 1},
#    {'country': 'US', 'city': 'BELTRAMI', 'count': 48525, 'locations': 1},
#    {'country': 'US', 'city': 'Bend', 'count': 66710, 'locations': 5},
#    {'country': 'AU', 'city': 'Bendigo', 'count': 15862, 'locations': 1},
#    {'country': 'IT', 'city': 'Benevento', 'count': 61573, 'locations': 1},
#    {'country': 'US', 'city': 'BENEWAH', 'count': 95714, 'locations': 2},
#    {'country': 'MX', 'city': 'Benito Juárez', 'count': 32052, 'locations': 1},
#    {'country': 'US', 'city': 'Bennington', 'count': 106352, 'locations': 1},
#    {'country': 'US', 'city': 'BENTON', 'count': 15661, 'locations': 2},
#    {'country': 'RS', 'city': 'Beočin', 'count': 10042, 'locations': 1},
#    {'country': 'RS', 'city': 'beograd', 'count': 10200, 'locations': 1},
#    {'country': 'RS', 'city': 'Beograd', 'count': 540886, 'locations': 24},
#    {'country': 'RS', 'city': 'Beograd ', 'count': 185986, 'locations': 1},
#    {'country': 'RS',
#     'city': 'Beograd Banovo brdo',
#     'count': 18433,
#     'locations': 1},
#    {'country': 'RS',
#     'city': 'Beograd Danijelova',
#     'count': 10076,
#     'locations': 1},
#    {'country': 'RS',
#     'city': 'Beograd-Leštane',
#     'count': 15089,
#     'locations': 1},
#    {'country': 'RS',
#     'city': 'Beograd-Mladenovac',
#     'count': 15108,
#     'locations': 1},
#    {'country': 'RS',
#     'city': 'Beograd Obrenovac Ušće',
#     'count': 12156,
#     'locations': 1},
#    {'country': 'RS',
#     'city': 'Beograd Topčiderska Zvezda',
#     'count': 13364,
#     'locations': 1},
#    {'country': 'ES', 'city': 'Berga', 'count': 28895, 'locations': 1},
#    {'country': 'NO', 'city': 'Bergen', 'count': 682293, 'locations': 5},
#    {'country': 'US', 'city': 'BERKELEY', 'count': 18432, 'locations': 1},
#    {'country': 'US', 'city': 'BERKS', 'count': 45671, 'locations': 1},
#    {'country': 'US', 'city': 'BERKSHIRE', 'count': 108605, 'locations': 3},
#    {'country': 'DE', 'city': 'Berlin', 'count': 113547, 'locations': 2},
#    {'country': 'US', 'city': 'Berlin', 'count': 25756, 'locations': 1},
#    {'country': 'US', 'city': 'BERNALILLO', 'count': 20691, 'locations': 2},
#    {'country': 'NL',
#     'city': 'Beverwijk West',
#     'count': 103780,
#     'locations': 1},
#    {'country': 'US', 'city': 'BEXAR', 'count': 528, 'locations': 1},
#    {'country': 'GB', 'city': 'Bexley', 'count': 341949, 'locations': 4},
#    {'country': 'PL', 'city': 'Biała', 'count': 76513, 'locations': 1},
#    {'country': 'PL',
#     'city': 'Biała Podlaska',
#     'count': 167368,
#     'locations': 1},
#    {'country': 'PL', 'city': 'Białystok', 'count': 309518, 'locations': 5},
#    {'country': 'US', 'city': 'BIBB', 'count': 9412, 'locations': 1},
#    {'country': 'NL', 'city': 'Biddinghuizen', 'count': 163639, 'locations': 1},
#    {'country': 'IT', 'city': 'Biella', 'count': 47172, 'locations': 1},
#    {'country': 'PL', 'city': 'Bielsko-Biała', 'count': 250748, 'locations': 2},
#    {'country': 'NL',
#     'city': 'Biest Houtakker',
#     'count': 216694,
#     'locations': 1},
#    {'country': 'US', 'city': 'BIG HORN', 'count': 51413, 'locations': 1},
#    {'country': 'RO', 'city': 'Bihor', 'count': 27237, 'locations': 1},
#    {'country': 'ME', 'city': 'Bijelo Polje', 'count': 32128, 'locations': 1},
#    {'country': 'TR', 'city': 'Bilecik', 'count': 87691, 'locations': 2},
#    {'country': 'GB', 'city': 'Billingham', 'count': 46996, 'locations': 1},
#    {'country': 'TR', 'city': 'Bingöl', 'count': 7232, 'locations': 1},
#    {'country': 'NO', 'city': 'Birkenes', 'count': 55476, 'locations': 1},
#    {'country': 'US',
#     'city': 'Birmingham-Hoover',
#     'count': 618542,
#     'locations': 10},
#    {'country': 'KG', 'city': 'Bishkek', 'count': 35006, 'locations': 1},
#    {'country': 'US', 'city': 'Bishop', 'count': 912187, 'locations': 15},
#    {'country': 'US', 'city': 'Bismarck', 'count': 59586, 'locations': 1},
#    {'country': 'RO', 'city': 'Bistrita-RNMCA', 'count': 53186, 'locations': 1},
#    {'country': 'TR', 'city': 'Bitlis', 'count': 8134, 'locations': 1},
#    {'country': 'ES', 'city': 'Bizkaia', 'count': 911564, 'locations': 12},
#    {'country': 'GB', 'city': 'Blackburn', 'count': 49442, 'locations': 1},
#    {'country': 'US', 'city': 'BLAINE', 'count': 46860, 'locations': 1},
#    {'country': 'SE',
#     'city': 'Blekinge Kustvatten och Luftvårdsförbund',
#     'count': 362,
#     'locations': 1},
#    {'country': 'US', 'city': 'Bloomington', 'count': 76128, 'locations': 3},
#    {'country': 'US',
#     'city': 'Bloomington-Normal',
#     'count': 89078,
#     'locations': 1},
#    {'country': 'NO', 'city': 'Bodø', 'count': 88326, 'locations': 1},
#    {'country': 'PL', 'city': 'Boguchwała', 'count': 1794, 'locations': 1},
#    {'country': 'US', 'city': 'BOISE', 'count': 101155, 'locations': 2},
#    {'country': 'US',
#     'city': 'Boise City-Nampa',
#     'count': 252703,
#     'locations': 2},
#    {'country': 'ZA',
#     'city': 'Bojanala Platinum',
#     'count': 162964,
#     'locations': 5},
#    {'country': 'US', 'city': 'BOLIVAR', 'count': 68207, 'locations': 1},
#    {'country': 'TR', 'city': 'Bolu', 'count': 88553, 'locations': 3},
#    {'country': 'IT', 'city': 'Bolzano/Bozen', 'count': 253486, 'locations': 7},
#    {'country': 'US', 'city': 'BONNER', 'count': 104886, 'locations': 2},
#    {'country': 'US', 'city': 'BOONE', 'count': 7728, 'locations': 1},
#    {'country': 'RS', 'city': 'Bor', 'count': 57695, 'locations': 3},
#    {'country': 'RS', 'city': 'Bor Krivelj', 'count': 2028, 'locations': 1},
#    {'country': 'PL', 'city': 'Borówiec', 'count': 148474, 'locations': 2},
#    {'country': 'RS', 'city': 'Bor Slatina', 'count': 2337, 'locations': 1},
#    {'country': 'PL', 'city': 'Borsukowizna', 'count': 165209, 'locations': 1},
#    {'country': 'US',
#     'city': 'Boston-Cambridge-Quincy',
#     'count': 882417,
#     'locations': 17},
#    {'country': 'NL', 'city': 'Botlek', 'count': 23372, 'locations': 1},
#    {'country': 'RO', 'city': 'Botosani-RNMCA', 'count': 62781, 'locations': 1},
#    {'country': 'FR',
#     'city': 'Bouches-du-Rhône',
#     'count': 1582906,
#     'locations': 22},
#    {'country': 'US', 'city': 'Boulder', 'count': 46370, 'locations': 2},
#    {'country': 'US', 'city': 'BOULDER', 'count': 41775, 'locations': 1},
#    {'country': 'US', 'city': 'BOUNDARY', 'count': 81134, 'locations': 3},
#    {'country': 'GB', 'city': 'Bournemouth', 'count': 153300, 'locations': 1},
#    {'country': 'US', 'city': 'Bowling Green', 'count': 72801, 'locations': 1},
#    {'country': 'US', 'city': 'BOX ELDER', 'count': 8786, 'locations': 1},
#    {'country': 'GB', 'city': 'Bradford', 'count': 5093, 'locations': 1},
#    {'country': 'US', 'city': 'BRADFORD', 'count': 88752, 'locations': 1},
#    {'country': 'RO', 'city': 'Brăila', 'count': 120632, 'locations': 3},
#    {'country': 'RO', 'city': 'Braila-RNMCA', 'count': 1117, 'locations': 3},
#    {'country': 'US', 'city': 'Brainerd', 'count': 87707, 'locations': 1},
#    {'country': 'DE', 'city': 'Brandenburg', 'count': 402836, 'locations': 7},
#    {'country': 'RO', 'city': 'Braşov', 'count': 35069, 'locations': 2},
#    {'country': 'RO', 'city': 'Brasov-RNMCA', 'count': 46992, 'locations': 4},
#    {'country': 'SK',
#     'city': 'Bratislavský kraj',
#     'count': 560727,
#     'locations': 3},
#    {'country': 'NL', 'city': 'Breda', 'count': 380418, 'locations': 2},
#    {'country': 'DE', 'city': 'Bremen', 'count': 77918, 'locations': 1},
#    {'country': 'GB', 'city': 'Brent', 'count': 171407, 'locations': 4},
#    {'country': 'NL', 'city': 'Breukelen', 'count': 216775, 'locations': 1},
#    {'country': 'US', 'city': 'BREWSTER', 'count': 60994, 'locations': 1},
#    {'country': 'XK', 'city': 'Brezovica', 'count': 4153, 'locations': 1},
#    {'country': 'US',
#     'city': 'Bridgeport-Stamford-Norwalk',
#     'count': 365919,
#     'locations': 5},
#    {'country': 'AU', 'city': 'Bright', 'count': 9312, 'locations': 1},
#    {'country': 'GB', 'city': 'Brighton', 'count': 132197, 'locations': 1},
#    {'country': 'GB',
#     'city': 'Brighton and Hove',
#     'count': 34151,
#     'locations': 1},
#    {'country': 'GB', 'city': 'Bristol', 'count': 19018, 'locations': 1},
#    {'country': 'US', 'city': 'BRISTOL', 'count': 41680, 'locations': 1},
#    {'country': 'CA',
#     'city': 'BRITISH COLUMBIA',
#     'count': 4176610,
#     'locations': 48},
#    {'country': 'GB', 'city': 'Bromley', 'count': 53250, 'locations': 1},
#    {'country': 'US', 'city': 'BROOKINGS', 'count': 134368, 'locations': 1},
#    {'country': 'US', 'city': 'BROWN', 'count': 53508, 'locations': 1},
#    {'country': 'US',
#     'city': 'Brownsville-Harlingen',
#     'count': 14851,
#     'locations': 1},
#    {'country': 'NO', 'city': 'Brumunddal', 'count': 5280, 'locations': 1},
#    {'country': 'US', 'city': 'Brunswick', 'count': 66141, 'locations': 1},
#    {'country': 'BE', 'city': 'Brussels', 'count': 103950, 'locations': 16},
#    {'country': 'BE',
#     'city': 'Brussels-Capital Region',
#     'count': 270078,
#     'locations': 7},
#    {'country': 'AT', 'city': 'Bryan Hellack', 'count': 802, 'locations': 1},
#    {'country': 'DE', 'city': 'Bryan Hellack', 'count': 294623, 'locations': 5},
#    {'country': 'PL', 'city': 'Brzeg', 'count': 36786, 'locations': 1},
#    {'country': 'RO', 'city': 'Bucureşti', 'count': 335709, 'locations': 6},
#    {'country': 'RO',
#     'city': 'Bucuresti-RNMCA',
#     'count': 20957,
#     'locations': 38},
#    {'country': 'HU',
#     'city': 'Budapest Budatétény',
#     'count': 15393,
#     'locations': 1},
#    {'country': 'HU',
#     'city': 'Budapest Csepel',
#     'count': 12105,
#     'locations': 1},
#    {'country': 'HU',
#     'city': 'Budapest Erzsébet tér',
#     'count': 15907,
#     'locations': 1},
#    {'country': 'HU',
#     'city': 'Budapest Gergely utca',
#     'count': 15800,
#     'locations': 1},
#    {'country': 'HU',
#     'city': 'Budapest Gilice tér',
#     'count': 21394,
#     'locations': 1},
#    {'country': 'HU',
#     'city': 'Budapest Honvéd',
#     'count': 13712,
#     'locations': 1},
#    {'country': 'HU',
#     'city': 'Budapest Káposztásmegyer',
#     'count': 4161,
#     'locations': 1},
#    {'country': 'HU',
#     'city': 'Budapest Kőrakás park',
#     'count': 23720,
#     'locations': 1},
#    {'country': 'HU',
#     'city': 'Budapest Kosztolányi D. tér',
#     'count': 12158,
#     'locations': 1},
#    {'country': 'LA', 'city': 'Bueng Kan', 'count': 35413, 'locations': 2},
#    {'country': 'AR', 'city': 'Buenos Aires', 'count': 214631, 'locations': 6},
#    {'country': 'US',
#     'city': 'Buffalo-Niagara Falls',
#     'count': 153413,
#     'locations': 4},
#    {'country': 'TR', 'city': 'Burdur', 'count': 33083, 'locations': 2},
#    {'country': 'SK', 'city': 'Burgenland', 'count': 114164, 'locations': 1},
#    {'country': 'AT', 'city': 'Burgenland', 'count': 227858, 'locations': 2},
#    {'country': 'TH', 'city': 'Buriram', 'count': 53242, 'locations': 1},
#    {'country': 'US', 'city': 'BURKE', 'count': 49048, 'locations': 1},
#    {'country': 'US',
#     'city': 'Burlington-South Burlington',
#     'count': 338739,
#     'locations': 2},
#    {'country': 'TR', 'city': 'Bursa', 'count': 291823, 'locations': 9},
#    {'country': 'GB', 'city': 'Bury', 'count': 105301, 'locations': 1},
#    {'country': 'GB', 'city': 'Bush Estate', 'count': 110622, 'locations': 1},
#    {'country': 'US', 'city': 'BUTLER', 'count': 199657, 'locations': 5},
#    {'country': 'US', 'city': 'BUTTE', 'count': 331389, 'locations': 3},
#    {'country': 'RO', 'city': 'Buzău', 'count': 55644, 'locations': 1},
#    {'country': 'RO', 'city': 'Buzau-RNMCA', 'count': 2595, 'locations': 2},
#    {'country': 'PL', 'city': 'Bydgoszcz', 'count': 199140, 'locations': 3},
#    {'country': 'PL', 'city': 'Bytów', 'count': 1552, 'locations': 2},
#    {'country': 'US', 'city': 'CA8 - ARB', 'count': 661, 'locations': 7},
#    {'country': 'NL', 'city': 'Cabauw', 'count': 299947, 'locations': 1},
#    {'country': 'US', 'city': 'CABELL', 'count': 15915, 'locations': 1},
#    {'country': 'RS', 'city': 'Čačak ', 'count': 14352, 'locations': 1},
#    {'country': 'US', 'city': 'CACHE', 'count': 163578, 'locations': 1},
#    {'country': 'MX',
#     'city': 'Cadereyta Jiménez',
#     'count': 61673,
#     'locations': 1},
#    {'country': 'US', 'city': 'Cadillac', 'count': 148374, 'locations': 1},
#    {'country': 'CL', 'city': 'Calama', 'count': 589636, 'locations': 7},
#    {'country': 'US', 'city': 'CALAVERAS', 'count': 94557, 'locations': 1},
#    {'country': 'CO', 'city': 'Caldas', 'count': 59164, 'locations': 1},
#    {'country': 'MX', 'city': 'Calimaya', 'count': 37076, 'locations': 1},
#    {'country': 'MX', 'city': 'Calpulalpan', 'count': 719, 'locations': 1},
#    {'country': 'US', 'city': 'Cambridge', 'count': 30888, 'locations': 1},
#    {'country': 'GB', 'city': 'Cambridge', 'count': 50332, 'locations': 1},
#    {'country': 'US', 'city': 'CAMERON', 'count': 271, 'locations': 1},
#    {'country': 'BR', 'city': 'Campinas', 'count': 108213, 'locations': 3},
#    {'country': 'IT', 'city': 'Campobasso', 'count': 13204, 'locations': 1},
#    {'country': 'TR', 'city': 'Çanakkale', 'count': 83316, 'locations': 2},
#    {'country': 'AU', 'city': 'Canberra', 'count': 426982, 'locations': 4},
#    {'country': 'TR', 'city': 'Çankırı', 'count': 25406, 'locations': 1},
#    {'country': 'GB', 'city': 'Canterbury', 'count': 122595, 'locations': 1},
#    {'country': 'FR',
#     'city': 'Canton de Genève',
#     'count': 341536,
#     'locations': 4},
#    {'country': 'FR',
#     'city': 'Canton de Gen��ve',
#     'count': 426,
#     'locations': 1},
#    {'country': 'CH', 'city': 'Canton de Vaud', 'count': 1138, 'locations': 1},
#    {'country': 'CH',
#     'city': 'Canton du Valais',
#     'count': 115539,
#     'locations': 1},
#    {'country': 'IT', 'city': 'Cantone Ticino', 'count': 1140, 'locations': 1},
#    {'country': 'US',
#     'city': 'Canton-Massillon',
#     'count': 144021,
#     'locations': 4},
#    {'country': 'US', 'city': 'CANYON', 'count': 11240, 'locations': 1},
#    {'country': 'US',
#     'city': 'Cape Coral-Fort Myers',
#     'count': 41041,
#     'locations': 1},
#    {'country': 'ZA', 'city': 'Cape Winelands', 'count': 86940, 'locations': 3},
#    {'country': 'ZA', 'city': 'Capricorn', 'count': 43755, 'locations': 1},
#    {'country': 'BR', 'city': 'Carapicuíba', 'count': 49029, 'locations': 1},
#    {'country': 'RO', 'city': 'Caras-RNMCA', 'count': 66127, 'locations': 2},
#    {'country': 'RO', 'city': 'Caraş-Severin', 'count': 52648, 'locations': 1},
#    {'country': 'US', 'city': 'CARBON', 'count': 123045, 'locations': 1},
#    {'country': 'GB', 'city': 'Cardiff', 'count': 270987, 'locations': 1},
#    {'country': 'US', 'city': 'CARIBOU', 'count': 68722, 'locations': 2},
#    {'country': 'US',
#     'city': 'Carlsbad-Artesia',
#     'count': 94458,
#     'locations': 1},
#    {'country': 'US', 'city': 'CARLTON', 'count': 83220, 'locations': 1},
#    {'country': 'US', 'city': 'CARSON CITY', 'count': 94719, 'locations': 1},
#    {'country': 'US', 'city': 'CARTER', 'count': 43355, 'locations': 1},
#    {'country': 'US', 'city': 'CASCADE', 'count': 49166, 'locations': 1},
#    {'country': 'IT', 'city': 'Caserta', 'count': 40481, 'locations': 1},
#    {'country': 'US', 'city': 'Casper', 'count': 123389, 'locations': 1},
#    {'country': 'US', 'city': 'CASS', 'count': 41520, 'locations': 1},
#    {'country': 'US', 'city': 'CASWELL', 'count': 31387, 'locations': 1},
#    {'country': 'BR', 'city': 'Catanduva', 'count': 50590, 'locations': 1},
#    {'country': 'PR', 'city': 'CATANO', 'count': 36228, 'locations': 1},
#    {'country': 'CL', 'city': 'Catemu', 'count': 151118, 'locations': 3},
#    {'country': 'CL', 'city': 'Cauquenes', 'count': 34035, 'locations': 1},
#    {'country': 'CN', 'city': 'Causeway Bay', 'count': 212114, 'locations': 1},
#    {'country': 'ES', 'city': 'CCAA Andaluc��a', 'count': 789, 'locations': 3},
#    {'country': 'ES',
#     'city': 'CCAA Andalucía',
#     'count': 7984822,
#     'locations': 81},
#    {'country': 'ES', 'city': 'CCAA Aragón', 'count': 438692, 'locations': 8},
#    {'country': 'ES',
#     'city': 'CCAA Asturias',
#     'count': 2383320,
#     'locations': 24},
#    {'country': 'ES',
#     'city': 'CCAA Cantabria',
#     'count': 751891,
#     'locations': 9},
#    {'country': 'ES',
#     'city': 'CCAA Castilla y Le��n',
#     'count': 1085,
#     'locations': 2},
#    {'country': 'ES',
#     'city': 'CCAA Castilla y León',
#     'count': 2345960,
#     'locations': 31},
#    {'country': 'ES',
#     'city': 'CCAA Cast. la Mancha',
#     'count': 895086,
#     'locations': 16},
#    {'country': 'ES', 'city': 'CCAA Catalu��a', 'count': 1197, 'locations': 1},
#    {'country': 'ES',
#     'city': 'CCAA Cataluña',
#     'count': 913431,
#     'locations': 19},
#    {'country': 'ES',
#     'city': 'CCAA Com. Valenciana',
#     'count': 4927666,
#     'locations': 60},
#    {'country': 'ES',
#     'city': 'CCAA Extremadura',
#     'count': 673408,
#     'locations': 11},
#    {'country': 'PT', 'city': 'CCAA Galicia', 'count': 78268, 'locations': 1},
#    {'country': 'ES', 'city': 'CCAA Galicia', 'count': 384028, 'locations': 48},
#    {'country': 'ES', 'city': 'CCAA La Rioja', 'count': 9002, 'locations': 6},
#    {'country': 'ES', 'city': 'CCAA Madrid', 'count': 125561, 'locations': 40},
#    {'country': 'ES', 'city': 'CCAA Murcia', 'count': 735925, 'locations': 9},
#    {'country': 'ES', 'city': 'CCAA Navarra', 'count': 14526, 'locations': 14},
#    {'country': 'ES',
#     'city': 'CCAA País Vasco',
#     'count': 424140,
#     'locations': 47},
#    {'country': 'SI', 'city': 'CE bolnica', 'count': 42609, 'locations': 1},
#    {'country': 'US', 'city': 'CEDAR', 'count': 82678, 'locations': 1},
#    {'country': 'US', 'city': 'Cedar Rapids', 'count': 228426, 'locations': 4},
#    {'country': 'MX', 'city': 'Celaya', 'count': 110275, 'locations': 3},
#    {'country': 'SI', 'city': 'CE Ljubljanska', 'count': 16486, 'locations': 1},
#    {'country': 'CN', 'city': 'Central', 'count': 207547, 'locations': 1},
#    {'country': 'AU', 'city': 'Central Coast', 'count': 242928, 'locations': 1},
#    {'country': 'AU',
#     'city': 'Central Queensland',
#     'count': 232140,
#     'locations': 5},
#    {'country': 'GB',
#     'city': 'Central Scotland',
#     'count': 143399,
#     'locations': 1},
#    {'country': 'AU',
#     'city': 'Central Tablelands',
#     'count': 123138,
#     'locations': 2},
#    {'country': 'CN',
#     'city': 'Central & Western',
#     'count': 180248,
#     'locations': 1},
#    {'country': 'BR',
#     'city': 'Cerqueira César',
#     'count': 68390,
#     'locations': 1},
#    {'country': 'CL', 'city': 'Cerrillos', 'count': 10853, 'locations': 1},
#    {'country': 'CL', 'city': 'Cerro Navia', 'count': 217307, 'locations': 1},
#    {'country': 'TH', 'city': 'Chachoengsao', 'count': 159972, 'locations': 1},
#    {'country': 'TH', 'city': 'Chainat', 'count': 2005, 'locations': 1},
#    {'country': 'TH', 'city': 'Chaiyaphum', 'count': 12279, 'locations': 2},
#    {'country': 'MX', 'city': 'Chalco', 'count': 14222, 'locations': 1},
#    {'country': 'US', 'city': 'Chambersburg', 'count': 45639, 'locations': 1},
#    {'country': 'US', 'city': 'CHAMPAIGN', 'count': 48424, 'locations': 1},
#    {'country': 'US',
#     'city': 'Champaign-Urbana',
#     'count': 153100,
#     'locations': 2},
#    {'country': 'TH',
#     'city': 'Chang Wat Phetchaburi',
#     'count': 415,
#     'locations': 1},
#    {'country': 'TH', 'city': 'Chanthaburi', 'count': 46908, 'locations': 1},
#    {'country': 'FR',
#     'city': 'Charente-Maritime',
#     'count': 179709,
#     'locations': 1},
#    {'country': 'US', 'city': 'CHARLESTON', 'count': 18768, 'locations': 1},
#    {'country': 'US',
#     'city': 'Charleston-North Charleston',
#     'count': 278872,
#     'locations': 2},
#    {'country': 'US',
#     'city': 'Charlotte-Gastonia-Concord',
#     'count': 463185,
#     'locations': 8},
#    {'country': 'US',
#     'city': 'Charlottesville',
#     'count': 82286,
#     'locations': 1},
#    {'country': 'GB', 'city': 'Charlton', 'count': 129771, 'locations': 1},
#    {'country': 'GB', 'city': 'Chatham', 'count': 13115, 'locations': 1},
#    {'country': 'US', 'city': 'Chattanooga', 'count': 120594, 'locations': 7},
#    {'country': 'US', 'city': 'CHAUTAUQUA', 'count': 39495, 'locations': 1},
#    {'country': 'US', 'city': 'CHELAN', 'count': 100074, 'locations': 2},
#    {'country': 'PL', 'city': 'Chełm', 'count': 33668, 'locations': 2},
#    {'country': 'CN', 'city': 'Chengdu', 'count': 34316, 'locations': 1},
#    {'country': 'GB', 'city': 'Chepstow', 'count': 161207, 'locations': 1},
#    {'country': 'FR', 'city': 'Cher', 'count': 120430, 'locations': 1},
#    {'country': 'GB', 'city': 'Chesterfield', 'count': 329881, 'locations': 2},
#    {'country': 'US', 'city': 'CHESTERFIELD', 'count': 72429, 'locations': 1},
#    {'country': 'US', 'city': 'Cheyenne', 'count': 323990, 'locations': 4},
#    {'country': 'TH', 'city': 'Chiang Mai', 'count': 149924, 'locations': 7},
#    {'country': 'TH',
#     'city': 'Chiang Mai Province',
#     'count': 993,
#     'locations': 1},
#    {'country': 'MM', 'city': 'Chiang Rai', 'count': 92534, 'locations': 1},
#    {'country': 'LA', 'city': 'Chiang Rai', 'count': 4951, 'locations': 1},
#    {'country': 'TH', 'city': 'Chiang Rai', 'count': 170086, 'locations': 1},
#    {'country': 'US',
#     'city': 'Chicago-Naperville-Joliet',
#     'count': 1592699,
#     'locations': 33},
#    {'country': 'CN', 'city': 'Chico', 'count': 4, 'locations': 1},
#    {'country': 'US', 'city': 'Chico', 'count': 50799, 'locations': 3},
#    {'country': 'CL', 'city': 'Chiguayante', 'count': 172064, 'locations': 1},
#    {'country': 'MX', 'city': 'Chihuahua', 'count': 102260, 'locations': 3},
#    {'country': 'CL', 'city': 'Chillán', 'count': 206994, 'locations': 2},
#    {'country': 'PL', 'city': 'Chojnice', 'count': 36632, 'locations': 1},
#    {'country': 'PL', 'city': 'Chojnów', 'count': 1342, 'locations': 1},
#    {'country': 'TH', 'city': 'Chon buri', 'count': 32062, 'locations': 1},
#    {'country': 'TH', 'city': 'Chon Buri', 'count': 43124, 'locations': 1},
#    {'country': 'NZ', 'city': 'Christchurch', 'count': 8819, 'locations': 2},
#    {'country': 'US', 'city': 'CHRISTIAN', 'count': 13826, 'locations': 1},
#    {'country': 'AU', 'city': 'Churchill', 'count': 24909, 'locations': 1},
#    {'country': 'US', 'city': 'CHURCHILL', 'count': 50256, 'locations': 1},
#    {'country': 'PL', 'city': 'Ciechocinek', 'count': 85909, 'locations': 1},
#    {'country': 'PL', 'city': 'Cieszyn', 'count': 18154, 'locations': 1},
#    {'country': 'US',
#     'city': 'Cincinnati-Middletown',
#     'count': 989635,
#     'locations': 10},
#    {'country': 'ZA',
#     'city': 'City of Cape Town',
#     'count': 254687,
#     'locations': 13},
#    {'country': 'ZA',
#     'city': 'City  of  Ekurhuleni',
#     'count': 230775,
#     'locations': 11},
#    {'country': 'ZA',
#     'city': 'City of Johannesburg',
#     'count': 365787,
#     'locations': 9},
#    {'country': 'GB', 'city': 'City of London', 'count': 89801, 'locations': 6},
#    {'country': 'US',
#     'city': 'City of The Dalles',
#     'count': 5751,
#     'locations': 1},
#    {'country': 'ZA',
#     'city': 'City of Tshwane',
#     'count': 226119,
#     'locations': 12},
#    {'country': 'IT', 'city': 'Civitavecchia', 'count': 532529, 'locations': 8},
#    {'country': 'US', 'city': 'CLACKAMAS', 'count': 18931, 'locations': 2},
#    {'country': 'US', 'city': 'CLAIBORNE', 'count': 36219, 'locations': 1},
#    {'country': 'US', 'city': 'CLARK', 'count': 578173, 'locations': 9},
#    {'country': 'US', 'city': 'Clarksville', 'count': 32831, 'locations': 1},
#    {'country': 'US', 'city': 'CLAY', 'count': 27021, 'locations': 2},
#    {'country': 'US',
#     'city': 'Cleveland-Elyria-Mentor',
#     'count': 859950,
#     'locations': 11},
#    {'country': 'US', 'city': 'Clinton', 'count': 145674, 'locations': 2},
#    {'country': 'US', 'city': 'CLINTON', 'count': 29419, 'locations': 1},
#    {'country': 'RO', 'city': 'Cluj', 'count': 83099, 'locations': 4},
#    {'country': 'RO', 'city': 'Cluj-RNMCA', 'count': 50689, 'locations': 4},
#    {'country': 'MX', 'city': 'Coatzacoalcos', 'count': 23086, 'locations': 1},
#    {'country': 'CL', 'city': 'Cochrane', 'count': 4650, 'locations': 1},
#    {'country': 'US', 'city': 'COCONINO', 'count': 43027, 'locations': 1},
#    {'country': 'US', 'city': 'CODINGTON', 'count': 109890, 'locations': 1},
#    {'country': 'US', 'city': 'COFFEE', 'count': 6147, 'locations': 1},
#    {'country': 'MX',
#     'city': 'Col. Indeco, Cd. Industrial',
#     'count': 1039,
#     'locations': 1},
#    {'country': 'US',
#     'city': 'College Station-Bryan',
#     'count': 8854,
#     'locations': 1},
#    {'country': 'US',
#     'city': 'Colorado Springs',
#     'count': 234068,
#     'locations': 4},
#    {'country': 'US', 'city': 'Columbia', 'count': 378266, 'locations': 6},
#    {'country': 'US', 'city': 'COLUMBIA', 'count': 58678, 'locations': 2},
#    {'country': 'US', 'city': 'Columbus', 'count': 633692, 'locations': 11},
#    {'country': 'US', 'city': 'COLUSA', 'count': 90041, 'locations': 1},
#    {'country': 'IT',
#     'city': 'COMUNE DI BARI',
#     'count': 106374,
#     'locations': 4},
#    {'country': 'IT',
#     'city': 'COMUNE DI BARLETTA',
#     'count': 37401,
#     'locations': 1},
#    {'country': 'IT',
#     'city': 'COMUNE DI LECCE',
#     'count': 78774,
#     'locations': 2},
#    {'country': 'GN', 'city': 'Conakry', 'count': 26713, 'locations': 1},
#    {'country': 'CL', 'city': 'Concón', 'count': 473731, 'locations': 5},
#    {'country': 'US', 'city': 'Concord', 'count': 28584, 'locations': 1},
#    {'country': 'RO', 'city': 'Constanţa', 'count': 140467, 'locations': 5},
#    {'country': 'RO',
#     'city': 'Constanta-RNMCA',
#     'count': 33538,
#     'locations': 7},
#    {'country': 'ES', 'city': 'Constantí', 'count': 69639, 'locations': 1},
#    {'country': 'US', 'city': 'CONVERSE', 'count': 179955, 'locations': 1},
#    {'country': 'US', 'city': 'COOK', 'count': 45560, 'locations': 1},
#    {'country': 'US', 'city': 'Cookeville', 'count': 42766, 'locations': 1},
#    {'country': 'US', 'city': 'COOS', 'count': 25288, 'locations': 2},
#    {'country': 'CO', 'city': 'Copacabana', 'count': 36192, 'locations': 1},
#    {'country': 'CL', 'city': 'Copiapó', 'count': 237957, 'locations': 5},
#    {'country': 'CL', 'city': 'Coquimbo', 'count': 106876, 'locations': 2},
#    {'country': 'ES', 'city': 'Córdoba', 'count': 162639, 'locations': 2},
#    {'country': 'IE', 'city': 'Cork City', 'count': 132383, 'locations': 2},
#    {'country': 'US', 'city': 'Corning', 'count': 49625, 'locations': 1},
#    {'country': 'MX', 'city': 'Coronango', 'count': 46426, 'locations': 1},
#    {'country': 'CL', 'city': 'Coronel', 'count': 132708, 'locations': 2},
#    {'country': 'US', 'city': 'Corpus Christi', 'count': 67807, 'locations': 4},
#    {'country': 'MX', 'city': 'Corregidora', 'count': 24040, 'locations': 1},
#    {'country': 'FR', 'city': 'Corrèze', 'count': 140456, 'locations': 1},
#    {'country': 'FR', 'city': 'Corse-du-Sud', 'count': 96436, 'locations': 1},
#    {'country': 'US', 'city': 'Corsicana', 'count': 94986, 'locations': 1},
#    {'country': 'TR', 'city': 'Çorum', 'count': 149863, 'locations': 3},
#    {'country': 'FR', 'city': "Côte-d'Or", 'count': 316600, 'locations': 3},
#    {'country': 'TT', 'city': 'Couva', 'count': 7845, 'locations': 1},
#    {'country': 'RO', 'city': 'Covasna-RNMCA', 'count': 9021, 'locations': 3},
#    {'country': 'GB', 'city': 'Coventry', 'count': 201035, 'locations': 1},
#    {'country': 'CL', 'city': 'Coyhaique', 'count': 342626, 'locations': 2},
#    {'country': 'MX', 'city': 'Coyoacán', 'count': 74566, 'locations': 2},
#    {'country': 'FR', 'city': 'Creuse', 'count': 177179, 'locations': 2},
#    {'country': 'SI', 'city': 'Črna na Koroškem', 'count': 912, 'locations': 1},
#    {'country': 'GB',
#     'city': 'Crompton Way   OL2 8AQ',
#     'count': 44474,
#     'locations': 1},
#    {'country': 'GB', 'city': 'Croydon', 'count': 48663, 'locations': 3},
#    {'country': 'MX',
#     'city': 'Cuajimalpa de Morelos',
#     'count': 12922,
#     'locations': 1},
#    {'country': 'MX',
#     'city': 'Cuautitlán Izcalli',
#     'count': 29832,
#     'locations': 1},
#    {'country': 'MX', 'city': 'Cuautla', 'count': 21648, 'locations': 1},
#    {'country': 'BR', 'city': 'Cubatão', 'count': 52240, 'locations': 1},
#    {'country': 'ES', 'city': 'Cubelles', 'count': 61493, 'locations': 1},
#    {'country': 'MX', 'city': 'Cuernavaca', 'count': 50275, 'locations': 1},
#    {'country': 'US', 'city': 'CUMBERLAND', 'count': 8650, 'locations': 1},
#    {'country': 'CL', 'city': 'Curanilahue', 'count': 44974, 'locations': 1},
#    {'country': 'CL', 'city': 'Curicó', 'count': 106830, 'locations': 1},
#    {'country': 'US', 'city': 'CUSTER', 'count': 160025, 'locations': 2},
#    {'country': 'US', 'city': 'CUYAHOGA', 'count': 104074, 'locations': 2},
#    {'country': 'PL', 'city': 'Czerniawa', 'count': 10434, 'locations': 1},
#    {'country': 'PL',
#     'city': 'Czerwionka-Leszczyny',
#     'count': 35966,
#     'locations': 1},
#    {'country': 'PL', 'city': 'Częstochowa', 'count': 269756, 'locations': 2},
#    {'country': 'PL', 'city': 'Dąbki', 'count': 3013, 'locations': 1},
#    {'country': 'PL',
#     'city': 'Dąbrowa Górnicza',
#     'count': 210497,
#     'locations': 1},
#    {'country': 'US', 'city': 'DAKOTA', 'count': 174040, 'locations': 1},
#    {'country': 'SE',
#     'city': 'Dalarnas Luftvårdsförbund',
#     'count': 56143,
#     'locations': 2},
#    {'country': 'SE',
#     'city': 'Dalarnas Luftv��rdsförbund',
#     'count': 582,
#     'locations': 1},
#    {'country': 'US',
#     'city': 'Dallas-Fort Worth-Arlington',
#     'count': 973064,
#     'locations': 19},
#    {'country': 'US', 'city': 'Dalton', 'count': 33722, 'locations': 1},
#    {'country': 'RO', 'city': 'Dâmboviţa', 'count': 38114, 'locations': 1},
#    {'country': 'DK',
#     'city': 'Danish Air Quality Monitoring Programme',
#     'count': 735907,
#     'locations': 7},
#    {'country': 'DK',
#     'city': 'Danish Background Monitoring Network',
#     'count': 95898,
#     'locations': 1},
#    {'country': 'US',
#     'city': 'Daphne-Fairhope',
#     'count': 33403,
#     'locations': 1},
#    {'country': 'XK', 'city': 'Dardhishtë', 'count': 4870, 'locations': 1},
#    {'country': 'GB', 'city': 'Dartford', 'count': 60820, 'locations': 3},
#    {'country': 'US',
#     'city': 'Davenport-Moline-Rock Island',
#     'count': 394531,
#     'locations': 4},
#    {'country': 'US', 'city': 'DAWSON', 'count': 2463, 'locations': 1},
#    {'country': 'US', 'city': 'Dayton', 'count': 242052, 'locations': 5},
#    {'country': 'PL', 'city': 'Dębica', 'count': 7910, 'locations': 1},
#    {'country': 'HU',
#     'city': 'Debrecen Hajnal u.',
#     'count': 10065,
#     'locations': 1},
#    {'country': 'HU',
#     'city': 'Debrecen Klinika',
#     'count': 7797,
#     'locations': 1},
#    {'country': 'US', 'city': 'Decatur', 'count': 87861, 'locations': 2},
#    {'country': 'US', 'city': 'DE KALB', 'count': 41811, 'locations': 2},
#    {'country': 'US', 'city': 'DEL NORTE', 'count': 9464, 'locations': 2},
#    {'country': 'US',
#     'city': 'Deltona-Daytona Beach-Ormond Beach',
#     'count': 86382,
#     'locations': 1},
#    {'country': 'US', 'city': 'Deming', 'count': 45280, 'locations': 1},
# ...
#    {'country': 'ME', 'city': 'Gornje Mrke', 'count': 15280, 'locations': 1},
#    {'country': 'PL',
#     'city': 'Gorzów Wielkopolski',
#     'count': 231904,
#     'locations': 1},
#    {'country': 'US', 'city': 'GOSHEN', 'count': 16068, 'locations': 1},
#    {'country': 'SE',
#     'city': 'Göteborgsregionens luftvårdsförbund',
#     'count': 2872,
#     'locations': 5},
#    {'country': 'SE',
#     'city': 'Göteborgsregionens luftvårdsf��rbund',
#     'count': 331,
#     'locations': 2},
#    {'country': 'SE',
#     'city': 'Göteborgsregionens luftv��rdsförbund',
#     'count': 94,
#     'locations': 1},
#    {'country': 'US', 'city': 'GRAHAM', 'count': 36914, 'locations': 1},
#    {'country': 'BR',
#     'city': 'Grajaú-Parelheiros',
#     'count': 56935,
#     'locations': 1},
#    {'country': 'PL', 'city': 'Grajewo', 'count': 96575, 'locations': 1},
#    {'country': 'ES', 'city': 'Granada', 'count': 89757, 'locations': 1},
#    {'country': 'US', 'city': 'Granbury', 'count': 47745, 'locations': 1},
#    {'country': 'US', 'city': 'GRAND', 'count': 28113, 'locations': 1},
#    {'country': 'US', 'city': 'Grand Island', 'count': 21713, 'locations': 1},
#    {'country': 'US',
#     'city': 'Grand Junction',
#     'count': 113370,
#     'locations': 2},
#    {'country': 'US',
#     'city': 'Grand Rapids-Wyoming',
#     'count': 264373,
#     'locations': 3},
#    {'country': 'GB', 'city': 'Grangemouth', 'count': 64339, 'locations': 2},
#    {'country': 'PL', 'city': 'Granica', 'count': 7166, 'locations': 1},
#    {'country': 'ES', 'city': 'Granollers', 'count': 65911, 'locations': 1},
#    {'country': 'US', 'city': 'GRANT', 'count': 153662, 'locations': 7},
#    {'country': 'US', 'city': 'Grants Pass', 'count': 47922, 'locations': 1},
#    {'country': 'US', 'city': 'GRANVILLE', 'count': 3279, 'locations': 1},
#    {'country': 'US', 'city': 'Greeley', 'count': 140750, 'locations': 2},
#    {'country': 'US', 'city': 'Green Bay', 'count': 137180, 'locations': 3},
#    {'country': 'US', 'city': 'GREENBRIER', 'count': 24126, 'locations': 1},
#    {'country': 'US', 'city': 'GREENE', 'count': 123862, 'locations': 2},
#    {'country': 'US',
#     'city': 'Greensboro-High Point',
#     'count': 113873,
#     'locations': 2},
#    {'country': 'US', 'city': 'Greenville', 'count': 236283, 'locations': 3},
#    {'country': 'GB', 'city': 'Greenwich', 'count': 384887, 'locations': 9},
#    {'country': 'NO', 'city': 'Grenland', 'count': 322474, 'locations': 4},
#    {'country': 'NL', 'city': 'Groningen', 'count': 327299, 'locations': 2},
#    {'country': 'PL', 'city': 'Grudziądz', 'count': 112474, 'locations': 1},
#    {'country': 'IS', 'city': 'Grundartangi', 'count': 146139, 'locations': 2},
#    {'country': 'MX', 'city': 'Guadalajara', 'count': 83634, 'locations': 2},
#    {'country': 'MX', 'city': 'Guadalupe', 'count': 60819, 'locations': 1},
#    {'country': 'MX', 'city': 'Guanajuato', 'count': 8041, 'locations': 1},
#    {'country': 'MX', 'city': 'GUANAJUATO', 'count': 2203703, 'locations': 18},
#    {'country': 'CN', 'city': 'Guangzhou', 'count': 51648, 'locations': 1},
#    {'country': 'BR', 'city': 'Guaratinguetá', 'count': 45211, 'locations': 1},
#    {'country': 'BR', 'city': 'Guarulhos', 'count': 54133, 'locations': 2},
#    {'country': 'GT', 'city': 'Guatemala City', 'count': 49900, 'locations': 1},
#    {'country': 'ES', 'city': 'Guiamets, els', 'count': 27089, 'locations': 1},
#    {'country': 'US',
#     'city': 'Gulfport-Biloxi',
#     'count': 160855,
#     'locations': 2},
#    {'country': 'TR', 'city': 'Gümüşhane', 'count': 13646, 'locations': 1},
#    {'country': 'US', 'city': 'GUNNISON', 'count': 35800, 'locations': 1},
#    {'country': 'MX',
#     'city': 'Gustavo A. Madero',
#     'count': 415,
#     'locations': 1},
#    {'country': 'PL', 'city': 'Guty Duże', 'count': 151427, 'locations': 1},
#    {'country': 'HU', 'city': 'Győr 2 Ifjúság', 'count': 10067, 'locations': 1},
#    {'country': 'NL', 'city': 'Haarlem', 'count': 163644, 'locations': 1},
#    {'country': 'AE', 'city': 'Habshan', 'count': 18623, 'locations': 1},
#    {'country': 'GB', 'city': 'Hackney', 'count': 35293, 'locations': 2},
#    {'country': 'IS', 'city': 'Hafnarfjörður', 'count': 118957, 'locations': 3},
#    {'country': 'US',
#     'city': 'Hagerstown-Martinsburg',
#     'count': 113230,
#     'locations': 2},
#    {'country': 'TR', 'city': 'Hakkari', 'count': 8509, 'locations': 1},
#    {'country': 'CA', 'city': 'Halifax', 'count': 13429, 'locations': 1},
#    {'country': 'SE', 'city': 'Halmstad', 'count': 25584, 'locations': 1},
#    {'country': 'NO', 'city': 'Hamar', 'count': 137153, 'locations': 2},
#    {'country': 'DE', 'city': 'Hamburg', 'count': 47584, 'locations': 1},
#    {'country': 'US', 'city': 'HAMILTON', 'count': 83575, 'locations': 4},
#    {'country': 'US', 'city': 'HAMPDEN', 'count': 125451, 'locations': 1},
#    {'country': 'US', 'city': 'HANCOCK', 'count': 64273, 'locations': 3},
#    {'country': 'US',
#     'city': 'Hanford-Corcoran',
#     'count': 118431,
#     'locations': 2},
#    {'country': 'MK', 'city': 'Hani i Elezit', 'count': 72209, 'locations': 1},
#    {'country': 'PL', 'city': 'Hannes Brauer', 'count': 74552, 'locations': 1},
#    {'country': 'DE',
#     'city': 'Hannes Brauer',
#     'count': 840286,
#     'locations': 23},
#    {'country': 'VN', 'city': 'Hanoi', 'count': 18113, 'locations': 35},
#    {'country': 'RO', 'city': 'Harghita', 'count': 48222, 'locations': 1},
#    {'country': 'RO', 'city': 'Harghita-RNMCA', 'count': 1469, 'locations': 2},
#    {'country': 'GB', 'city': 'Haringey', 'count': 22011, 'locations': 1},
#    {'country': 'FI',
#     'city': 'Harjavallan verkko',
#     'count': 1524,
#     'locations': 2},
#    {'country': 'US', 'city': 'HARNEY', 'count': 46849, 'locations': 1},
#    {'country': 'US', 'city': 'Harriman', 'count': 43280, 'locations': 1},
#    {'country': 'US',
#     'city': 'Harrisburg-Carlisle',
#     'count': 189268,
#     'locations': 3},
#    {'country': 'US', 'city': 'Harrison', 'count': 39287, 'locations': 2},
#    {'country': 'US', 'city': 'Harrisonburg', 'count': 155978, 'locations': 1},
#    {'country': 'GB', 'city': 'Harrow', 'count': 35669, 'locations': 1},
#    {'country': 'US',
#     'city': 'Hartford-West Hartford-East Hartford',
#     'count': 450562,
#     'locations': 3},
#    {'country': 'TR', 'city': 'Hatay', 'count': 124604, 'locations': 5},
#    {'country': 'US', 'city': 'Hattiesburg', 'count': 53079, 'locations': 1},
#    {'country': 'FR',
#     'city': 'Haute-Garonne',
#     'count': 753514,
#     'locations': 10},
#    {'country': 'FR',
#     'city': 'Hautes-Pyrénées',
#     'count': 176930,
#     'locations': 2},
#    {'country': 'FR', 'city': 'Haute-Vienne', 'count': 202021, 'locations': 3},
#    {'country': 'GB', 'city': 'Havering', 'count': 80883, 'locations': 2},
#    {'country': 'US', 'city': 'HAWAII', 'count': 175888, 'locations': 6},
#    {'country': 'US', 'city': 'HAYS', 'count': 2244, 'locations': 1},
#    {'country': 'US', 'city': 'HAYWOOD', 'count': 64164, 'locations': 2},
#    {'country': 'NL', 'city': 'Heerlen', 'count': 232377, 'locations': 2},
#    {'country': 'US', 'city': 'Helena', 'count': 5630, 'locations': 1},
#    {'country': 'NL', 'city': 'Hellendoorn', 'count': 163650, 'locations': 1},
#    {'country': 'FI',
#     'city': 'Helsingin seudun verkko (HSY)',
#     'count': 864606,
#     'locations': 7},
#    {'country': 'US', 'city': 'HENDERSON', 'count': 14942, 'locations': 1},
#    {'country': 'US', 'city': 'HENNEPIN', 'count': 86671, 'locations': 3},
#    {'country': 'FR', 'city': 'Hérault', 'count': 345141, 'locations': 5},
#    {'country': 'HU', 'city': 'Hernádszurdok', 'count': 23583, 'locations': 1},
#    {'country': 'DE', 'city': 'Hessen', 'count': 107152, 'locations': 2},
#    {'country': 'US', 'city': 'HI1', 'count': 12549, 'locations': 17},
#    {'country': 'US',
#     'city': 'Hickory-Lenoir-Morganton',
#     'count': 37125,
#     'locations': 2},
#    {'country': 'GB', 'city': 'High Muffles', 'count': 127424, 'locations': 1},
#    {'country': 'US', 'city': 'HILL', 'count': 5357, 'locations': 1},
#    {'country': 'US', 'city': 'Hilo', 'count': 432037, 'locations': 5},
#    {'country': 'US', 'city': 'Hobbs', 'count': 133938, 'locations': 1},
#    {'country': 'VN',
#     'city': 'Ho Chi Minh City',
#     'count': 53467,
#     'locations': 1},
#    {'country': 'NL',
#     'city': 'Hoek v. Holland',
#     'count': 227511,
#     'locations': 1},
#    {'country': 'US',
#     'city': 'Holland-Grand Haven',
#     'count': 67442,
#     'locations': 1},
#    {'country': 'US', 'city': 'HOLMES', 'count': 86188, 'locations': 1},
#    {'country': 'US',
#     'city': 'Homosassa Springs',
#     'count': 85598,
#     'locations': 1},
#    {'country': 'CN', 'city': 'Hong Kong', 'count': 102672, 'locations': 1},
#    {'country': 'GB', 'city': 'Honiton', 'count': 83155, 'locations': 1},
#    {'country': 'US', 'city': 'Honolulu', 'count': 500851, 'locations': 3},
#    {'country': 'US', 'city': 'HOOD RIVER', 'count': 23391, 'locations': 1},
#    {'country': 'NL', 'city': 'Hoofddorp', 'count': 144214, 'locations': 1},
#    {'country': 'NL', 'city': 'Hoogvliet', 'count': 212428, 'locations': 1},
#    {'country': 'GB', 'city': 'Horley', 'count': 72018, 'locations': 1},
#    {'country': 'GB', 'city': 'Horsham', 'count': 11913, 'locations': 1},
#    {'country': 'DE', 'city': 'Horst Hempel', 'count': 955891, 'locations': 20},
#    {'country': 'HU', 'city': 'Hortobágy', 'count': 5739, 'locations': 1},
#    {'country': 'ES',
#     'city': "Hospitalet de Llobregat, l'",
#     'count': 53887,
#     'locations': 1},
#    {'country': 'US',
#     'city': 'Houma-Bayou Cane-Thibodaux',
#     'count': 101024,
#     'locations': 1},
#    {'country': 'US',
#     'city': 'Houston-Sugar Land-Baytown',
#     'count': 1094440,
#     'locations': 22},
#    {'country': 'US', 'city': 'HOWARD', 'count': 207689, 'locations': 1},
#    {'country': 'SI', 'city': 'Hrastnik', 'count': 22917, 'locations': 1},
#    {'country': 'CL', 'city': 'Hualqui', 'count': 192272, 'locations': 1},
#    {'country': 'CL', 'city': 'Huasco', 'count': 364467, 'locations': 9},
#    {'country': 'ES', 'city': 'Huelva', 'count': 280713, 'locations': 3},
#    {'country': 'US', 'city': 'HUGHES', 'count': 43557, 'locations': 1},
#    {'country': 'MX', 'city': 'Huichapan', 'count': 50521, 'locations': 1},
#    {'country': 'NL', 'city': 'Huijbergen', 'count': 163638, 'locations': 1},
#    {'country': 'GB', 'city': 'Hull', 'count': 253319, 'locations': 1},
#    {'country': 'US', 'city': 'HUMBOLDT', 'count': 49531, 'locations': 1},
#    {'country': 'RO', 'city': 'Hunedoara', 'count': 96576, 'locations': 2},
#    {'country': 'RO', 'city': 'Hunedoara-RNMCA', 'count': 380, 'locations': 1},
#    {'country': 'HU',
#     'city': 'Hungarian Air Quality Network',
#     'count': 3355419,
#     'locations': 20},
#    {'country': 'HU',
#     'city': 'Hungarian Regional Background Air Pollution  Monitoring Network',
#     'count': 66502,
#     'locations': 2},
#    {'country': 'US',
#     'city': 'Huntington-Ashland',
#     'count': 71122,
#     'locations': 3},
#    {'country': 'US', 'city': 'Huntsville', 'count': 72965, 'locations': 1},
#    {'country': 'NO', 'city': 'Hurdal', 'count': 48606, 'locations': 1},
#    {'country': 'US', 'city': 'HURON', 'count': 3146, 'locations': 1},
#    {'country': 'IS', 'city': 'Húsavík', 'count': 33397, 'locations': 2},
#    {'country': 'RO', 'city': 'Iaşi', 'count': 113940, 'locations': 3},
#    {'country': 'MD', 'city': 'Iasi-RNMCA', 'count': 22759, 'locations': 1},
#    {'country': 'RO', 'city': 'Iasi-RNMCA', 'count': 19712, 'locations': 4},
#    {'country': 'US', 'city': 'IDAHO', 'count': 117760, 'locations': 3},
#    {'country': 'US', 'city': 'Idaho Falls', 'count': 21189, 'locations': 1},
#    {'country': 'TR', 'city': 'Iğdır', 'count': 97862, 'locations': 2},
#    {'country': 'ES', 'city': 'Igualada', 'count': 2268, 'locations': 1},
#    {'country': 'NL', 'city': 'IJmuiden', 'count': 263041, 'locations': 1},
#    {'country': 'RO', 'city': 'Ilfov', 'count': 174307, 'locations': 2},
#    {'country': 'AU', 'city': 'Illawarra', 'count': 408819, 'locations': 2},
#    {'country': 'FR',
#     'city': 'Ille-et-Vilaine',
#     'count': 147931,
#     'locations': 2},
#    {'country': 'FI',
#     'city': 'Ilmatieteen laitoksen verkko',
#     'count': 582901,
#     'locations': 6},
#    {'country': 'RU',
#     'city': 'Ilmatieteen laitoksen verkko',
#     'count': 6555,
#     'locations': 1},
#    {'country': 'NG', 'city': 'Ilorin', 'count': 1132, 'locations': 1},
#    {'country': 'IT', 'city': 'Imperia', 'count': 46455, 'locations': 1},
#    {'country': 'IN', 'city': 'India', 'count': 184906, 'locations': 5},
#    {'country': 'US', 'city': 'Indiana', 'count': 65328, 'locations': 1},
#    {'country': 'US', 'city': 'Indianapolis', 'count': 607729, 'locations': 14},
#    {'country': 'FR', 'city': 'Indre-et-Loire', 'count': 45420, 'locations': 1},
#    {'country': 'FR', 'city': 'Ingrid Zell', 'count': 20337, 'locations': 1},
#    {'country': 'DE', 'city': 'Ingrid Zell', 'count': 406896, 'locations': 8},
#    {'country': 'CH', 'city': 'inLUFT', 'count': 94342, 'locations': 2},
#    {'country': 'PL', 'city': 'Inowrocław', 'count': 91993, 'locations': 1},
#    {'country': 'LT',
#     'city': 'Integrated Monitoring Network',
#     'count': 85687,
#     'locations': 3},
#    {'country': 'GB', 'city': 'Inverness', 'count': 15286, 'locations': 1},
#    {'country': 'US', 'city': 'INYO', 'count': 64303, 'locations': 5},
#    {'country': 'US', 'city': 'Iowa City', 'count': 39329, 'locations': 3},
#    {'country': 'MX', 'city': 'Irapuato', 'count': 109842, 'locations': 3},
#    {'country': 'IE',
#     'city': 'Ireland Air Quality e-Reporting monitoring network for compliance and informative reporting',
#     'count': 991573,
#     'locations': 27},
#    {'country': 'GB',
#     'city': 'Ireland Air Quality e-Reporting monitoring network for compliance and informative reporting',
#     'count': 79797,
#     'locations': 2},
#    {'country': 'US', 'city': 'IRON', 'count': 180700, 'locations': 2},
#    {'country': 'FR', 'city': 'Isère', 'count': 159572, 'locations': 2},
#    {'country': 'SI', 'city': 'Iskrba', 'count': 17962, 'locations': 1},
#    {'country': 'PK', 'city': 'Islamabad', 'count': 34592, 'locations': 1},
#    {'country': 'GB', 'city': 'Islington', 'count': 68131, 'locations': 2},
#    {'country': 'TR', 'city': 'Isparta', 'count': 21168, 'locations': 1},
#    {'country': 'TR', 'city': 'İstanbul', 'count': 349821, 'locations': 10},
#    {'country': 'CO', 'city': 'Itagüí', 'count': 112494, 'locations': 2},
#    {'country': 'IT', 'city': 'ITALGREEN', 'count': 17724, 'locations': 1},
#    {'country': 'US', 'city': 'Ithaca', 'count': 37480, 'locations': 1},
#    {'country': 'TR', 'city': 'İzmir', 'count': 526389, 'locations': 22},
#    {'country': 'MX', 'city': 'Iztacalco', 'count': 18046, 'locations': 1},
#    {'country': 'MX', 'city': 'Iztapalapa', 'count': 63540, 'locations': 2},
#    {'country': 'BR', 'city': 'Jacareí', 'count': 32648, 'locations': 1},
#    {'country': 'US', 'city': 'Jackson', 'count': 410944, 'locations': 5},
#    {'country': 'US', 'city': 'JACKSON', 'count': 214676, 'locations': 3},
#    {'country': 'US', 'city': 'Jacksonville', 'count': 493828, 'locations': 6},
#    {'country': 'ID', 'city': 'Jakarta', 'count': 65784, 'locations': 1},
#    {'country': 'MX', 'city': 'JALISCO', 'count': 174659, 'locations': 7},
#    {'country': 'SE', 'city': 'Jämtland', 'count': 66413, 'locations': 1},
#    {'country': 'PL', 'city': 'Janów Lubelski', 'count': 23346, 'locations': 1},
#    {'country': 'PL', 'city': 'Jarczew', 'count': 21600, 'locations': 1},
#    {'country': 'PL', 'city': 'Jarosław', 'count': 70530, 'locations': 1},
#    {'country': 'PL', 'city': 'Jasło', 'count': 152497, 'locations': 1},
#    {'country': 'PL',
#     'city': 'Jastrzębie-Zdrój',
#     'count': 22879,
#     'locations': 1},
#    {'country': 'BR', 'city': 'Jaú', 'count': 46, 'locations': 1},
#    {'country': 'PL', 'city': 'Jedlicze', 'count': 7560, 'locations': 1},
#    {'country': 'PL', 'city': 'Jedlina-Zdrój', 'count': 15771, 'locations': 1},
#    {'country': 'US', 'city': 'JEFFERSON', 'count': 200375, 'locations': 5},
#    {'country': 'US', 'city': 'Jefferson City', 'count': 33649, 'locations': 1},
#    {'country': 'PL', 'city': 'Jelenia Góra', 'count': 251296, 'locations': 1},
#    {'country': 'US', 'city': 'JERSEY', 'count': 69170, 'locations': 1}]})

# %%
pollutionDF = pd.DataFrame(data[1]['results'])

# %%
pollutionDF
# Out:
#     country            city     count  locations
# 0        TW                   4863951         66
# 1        JP                  24985118       1530
# 2        CN                    142407          1
# 3        US             007     20445          4
# 4        US             015      1025          1
# ..      ...             ...       ...        ...
# 995      PL   Jedlina-Zdrój     15771          1
# 996      US       JEFFERSON    200375          5
# 997      US  Jefferson City     33649          1
# 998      PL    Jelenia Góra    251296          1
# 999      US          JERSEY     69170          1
#
# [1000 rows x 4 columns]

# %%
pollutionDF.head()
# Out:
#   country city     count  locations
# 0      TW        4863951         66
# 1      JP       24985118       1530
# 2      CN         142407          1
# 3      US  007     20445          4
# 4      US  015      1025          1

# %%
# add a new column using existing column
pollutionDF['pollution_per100'] = pollutionDF['count']/100

# %%
# let's see the new column
pollutionDF.head()
# Out:
#   country city     count  locations  pollution_per100
# 0      TW        4863951         66          48639.51
# 1      JP       24985118       1530         249851.18
# 2      CN         142407          1           1424.07
# 3      US  007     20445          4            204.45
# 4      US  015      1025          1             10.25

# %%
# rename column headers
renamedDF = pollutionDF.rename(
    columns={
        'country': 'C_Code',
        'name' : 'C_Name',
    }
)

# %%
# see all the column names
pollutionDF.columns
# Out:
# Index(['country', 'city', 'count', 'locations', 'pollution_per100'], dtype='object')

# %%
renamedDF.columns
# Out:
# Index(['C_Code', 'city', 'count', 'locations', 'pollution_per100'], dtype='object')

# %%
renamedDF.head()
# Out:
#   C_Code city     count  locations  pollution_per100
# 0     TW        4863951         66          48639.51
# 1     JP       24985118       1530         249851.18
# 2     CN         142407          1           1424.07
# 3     US  007     20445          4            204.45
# 4     US  015      1025          1             10.25

# %% [markdown]
# ## Combine data from multiple tables
# - `pd.concat()` performs concatenatoins operations of multiple tables along one of the axis (row-wise or column-wise)
# - typically row-wise concatenation is a common operation
# - `concat` is general function provided in pandas module
#     - https://pandas.pydata.org/pandas-docs/stable/reference/general_functions.html
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html?highlight=pandas%20concat#pandas.concat
#
# ![](./images/08_concat_row1.svg)

# %%
# make a deep copy of dataframe/table
renamedDF1 = renamedDF.copy(deep=True)

# %%
renamedDF1.shape
# Out:
# (1000, 5)

# %%
# let's concatenate the two into a single table
combinedDF = pd.concat([renamedDF, renamedDF1], axis=0)

# %%
combinedDF.shape
# Out:
# (2000, 5)

# %% [markdown]
# ## Join tables using a common identifier
# - merge tables column-wise
# - the figures below show a left-join
#
# ![](./images/08_merge_left.svg)
#
# - can use `pd.merge()` general function provided in pandas module
#     - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.merge.html
# - DataFrame class also provides merge method
# - merge method provides how parameter to do various types of joins
#     - 'left', 'right', 'outer', 'inner', 'cross', default 'inner'
#     - `left`: use only keys from left frame, similar to a SQL left outer join; preserve key order.
#     - `right`: use only keys from right frame, similar to a SQL right outer join; preserve key order.
#     - `outer`: use union of keys from both frames, similar to a SQL full outer join; sort keys lexicographically.
#     - `inner`: use intersection of keys from both frames, similar to a SQL inner join; preserve the order of the left keys.
#     - `cross`: creates the cartesian product from both frames, preserves the order of the left keys.
# - `pandas.concat([df1, df2], axis=0)` is equivalent to `union` in SQL
#
# ![](./images/sqlJoins_7.webp)

# %%
# create a DF with key column lkey
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [1, 2, 3, 5]})

# %%
df1
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5

# %%
# create a DF with key colum rkey
df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [5, 6, 7, 8]})

# %%
df2
# Out:
#   rkey  value
# 0  foo      5
# 1  bar      6
# 2  baz      7
# 3  foo      8

# %%
# cross join
df1.merge(df2, left_on='lkey', right_on='rkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  foo        5  foo        5
# 3  foo        5  foo        8
# 4  bar        2  bar        6
# 5  baz        3  baz        7

# %%
# join on common column names
df1 = pd.DataFrame({'a': ['foo', 'bar'], 'b': [1, 2]})
df2 = pd.DataFrame({'a': ['foo', 'baz'], 'c': [3, 4]})

# %%
df1
# Out:
#      a  b
# 0  foo  1
# 1  bar  2

# %%
df2
# Out:
#      a  c
# 0  foo  3
# 1  baz  4

# %%
# inersection or inner join
df1.merge(df2, how='inner', on='a')
# Out:
#      a  b  c
# 0  foo  1  3

# %%
# left join
df1.merge(df2, how='left', on='a')
# Out:
#      a  b    c
# 0  foo  1  3.0
# 1  bar  2  NaN

# %%
# right join
df1.merge(df2, how='right', on='a')
# Out:
#      a    b  c
# 0  foo  1.0  3
# 1  baz  NaN  4

# %%
# outer join
df1.merge(df2, how='outer', on='a')
# Out:
#      a    b    c
# 0  foo  1.0  3.0
# 1  bar  2.0  NaN
# 2  baz  NaN  4.0

# %%
no2_url = 'https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/air_quality_no2_long.csv'
pm2_url = 'https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/air_quality_pm25_long.csv'
air_quality_stations_url = 'https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/air_quality_stations.csv'
air_qual_parameters_url = 'https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/air_quality_parameters.csv'

# %%
air_quality_no2 = pd.read_csv(no2_url)

# %%
air_quality_no2.head()
# Out:
#     city country                   date.utc location parameter  value   unit
# 0  Paris      FR  2019-06-21 00:00:00+00:00  FR04014       no2   20.0  µg/m³
# 1  Paris      FR  2019-06-20 23:00:00+00:00  FR04014       no2   21.8  µg/m³
# 2  Paris      FR  2019-06-20 22:00:00+00:00  FR04014       no2   26.5  µg/m³
# 3  Paris      FR  2019-06-20 21:00:00+00:00  FR04014       no2   24.9  µg/m³
# 4  Paris      FR  2019-06-20 20:00:00+00:00  FR04014       no2   21.4  µg/m³

# %%
air_quality_parameters = pd.read_csv(air_qual_parameters_url)

# %%
air_quality_parameters.head()
# Out:
#      id                                        description  name
# 0    bc                                       Black Carbon    BC
# 1    co                                    Carbon Monoxide    CO
# 2   no2                                   Nitrogen Dioxide   NO2
# 3    o3                                              Ozone    O3
# 4  pm10  Particulate matter less than 10 micrometers in...  PM10

# %%
# column parameter in air_quality_no2 table and id in air_quality_parameters are common
air_quality = pd.merge(air_quality_no2, air_quality_parameters, how='left', left_on='parameter', right_on='id')

# %%
air_quality.head(10)
# Out:
#     city country                   date.utc location parameter  value   unit  \
# 0  Paris      FR  2019-06-21 00:00:00+00:00  FR04014       no2   20.0  µg/m³
# 1  Paris      FR  2019-06-20 23:00:00+00:00  FR04014       no2   21.8  µg/m³
# 2  Paris      FR  2019-06-20 22:00:00+00:00  FR04014       no2   26.5  µg/m³
# 3  Paris      FR  2019-06-20 21:00:00+00:00  FR04014       no2   24.9  µg/m³
# 4  Paris      FR  2019-06-20 20:00:00+00:00  FR04014       no2   21.4  µg/m³
# 5  Paris      FR  2019-06-20 19:00:00+00:00  FR04014       no2   25.3  µg/m³
# 6  Paris      FR  2019-06-20 18:00:00+00:00  FR04014       no2   23.9  µg/m³
# 7  Paris      FR  2019-06-20 17:00:00+00:00  FR04014       no2   23.2  µg/m³
# 8  Paris      FR  2019-06-20 16:00:00+00:00  FR04014       no2   19.0  µg/m³
# 9  Paris      FR  2019-06-20 15:00:00+00:00  FR04014       no2   19.3  µg/m³
#
#     id       description name
# 0  no2  Nitrogen Dioxide  NO2
# 1  no2  Nitrogen Dioxide  NO2
# 2  no2  Nitrogen Dioxide  NO2
# 3  no2  Nitrogen Dioxide  NO2
# 4  no2  Nitrogen Dioxide  NO2
# 5  no2  Nitrogen Dioxide  NO2
# 6  no2  Nitrogen Dioxide  NO2
# 7  no2  Nitrogen Dioxide  NO2
# 8  no2  Nitrogen Dioxide  NO2
# 9  no2  Nitrogen Dioxide  NO2

# %%
air_quality.tail(10)
# Out:
#         city country                   date.utc            location parameter  \
# 2058  London      GB  2019-05-07 11:00:00+00:00  London Westminster       no2
# 2059  London      GB  2019-05-07 10:00:00+00:00  London Westminster       no2
# 2060  London      GB  2019-05-07 09:00:00+00:00  London Westminster       no2
# 2061  London      GB  2019-05-07 08:00:00+00:00  London Westminster       no2
# 2062  London      GB  2019-05-07 07:00:00+00:00  London Westminster       no2
# 2063  London      GB  2019-05-07 06:00:00+00:00  London Westminster       no2
# 2064  London      GB  2019-05-07 04:00:00+00:00  London Westminster       no2
# 2065  London      GB  2019-05-07 03:00:00+00:00  London Westminster       no2
# 2066  London      GB  2019-05-07 02:00:00+00:00  London Westminster       no2
# 2067  London      GB  2019-05-07 01:00:00+00:00  London Westminster       no2
#
#       value   unit   id       description name
# 2058   21.0  µg/m³  no2  Nitrogen Dioxide  NO2
# 2059   21.0  µg/m³  no2  Nitrogen Dioxide  NO2
# 2060   28.0  µg/m³  no2  Nitrogen Dioxide  NO2
# 2061   32.0  µg/m³  no2  Nitrogen Dioxide  NO2
# 2062   32.0  µg/m³  no2  Nitrogen Dioxide  NO2
# 2063   26.0  µg/m³  no2  Nitrogen Dioxide  NO2
# 2064   16.0  µg/m³  no2  Nitrogen Dioxide  NO2
# 2065   19.0  µg/m³  no2  Nitrogen Dioxide  NO2
# 2066   19.0  µg/m³  no2  Nitrogen Dioxide  NO2
# 2067   23.0  µg/m³  no2  Nitrogen Dioxide  NO2

# %% [markdown]
# ## Working with textual data
# - can apply all the Python string methods on text data
# - let's work on Titanic dataset

# %%
import pandas as pd

# %%
titanic = pd.read_csv('data/titanic.csv', index_col="PassengerId")

# %%
titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
# convert Names to lowercase
titanic["Name"] = titanic["Name"].str.lower()

# %%
titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      braund, mr. owen harris    male  22.0
# 2            cumings, mrs. john bradley (florence briggs th...  female  38.0
# 3                                       heikkinen, miss. laina  female  26.0
# 4                 futrelle, mrs. jacques heath (lily may peel)  female  35.0
# 5                                     allen, mr. william henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
# Create a new column "Surname" that contains the last name by extracting the part before the comma in Name
titanic["Name"].str.split(",")
# Out:
# PassengerId
# 1                             [braund,  mr. owen harris]
# 2      [cumings,  mrs. john bradley (florence briggs ...
# 3                              [heikkinen,  miss. laina]
# 4        [futrelle,  mrs. jacques heath (lily may peel)]
# 5                            [allen,  mr. william henry]
#                              ...
# 887                             [montvila,  rev. juozas]
# 888                      [graham,  miss. margaret edith]
# 889          [johnston,  miss. catherine helen "carrie"]
# 890                             [behr,  mr. karl howell]
# 891                               [dooley,  mr. patrick]
# Name: Name, Length: 891, dtype: object

# %%
titanic["Surname"] = titanic["Name"].str.split(",").str.get(0)

# %%
titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      braund, mr. owen harris    male  22.0
# 2            cumings, mrs. john bradley (florence briggs th...  female  38.0
# 3                                       heikkinen, miss. laina  female  26.0
# 4                 futrelle, mrs. jacques heath (lily may peel)  female  35.0
# 5                                     allen, mr. william henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked    Surname
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S     braund
# 2                1      0          PC 17599  71.2833   C85        C    cumings
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S  heikkinen
# 4                1      0            113803  53.1000  C123        S   futrelle
# 5                0      0            373450   8.0500   NaN        S      allen

# %%
# extract the passengers info with the Name that contains "henry" on board of the Titanic
titanic[titanic["Name"].str.contains("henry")]
# Out:
#              Survived  Pclass  \
# PassengerId
# 5                   0       3
# 13                  0       3
# 53                  1       1
# 63                  0       1
# 160                 0       3
# 177                 0       3
# 210                 1       1
# 213                 0       3
# 223                 0       3
# 228                 0       3
# 231                 1       1
# 240                 0       2
# 265                 0       3
# 272                 1       3
# 335                 1       1
# 348                 1       3
# 386                 0       2
# 412                 0       3
# 477                 0       2
# 483                 0       3
# 509                 0       3
# 595                 0       2
# 624                 0       3
# 631                 1       1
# 634                 0       1
# 646                 1       1
# 661                 1       1
# 673                 0       2
# 696                 0       2
# 706                 0       2
# 723                 0       2
# 724                 0       2
# 727                 1       2
# 885                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 5                                     allen, mr. william henry    male  35.0
# 13                              saundercock, mr. william henry    male  20.0
# 53                    harper, mrs. henry sleeper (myna haxtun)  female  49.0
# 63                                 harris, mr. henry birkhardt    male  45.0
# 160                                 sage, master. thomas henry    male   NaN
# 177                              lefebre, master. henry forbes    male   NaN
# 210                                           blank, mr. henry    male  40.0
# 213                                     perkin, mr. john henry    male  22.0
# 223                                    green, mr. george henry    male  51.0
# 228                            lovell, mr. john hall ("henry")    male  20.5
# 231               harris, mrs. henry birkhardt (irene wallach)  female  35.0
# 240                                     hunt, mr. george henry    male  33.0
# 265                                         henry, miss. delia  female   NaN
# 272                               tornquist, mr. william henry    male  25.0
# 335          frauenthal, mrs. henry william (clara heinshei...  female   NaN
# 348                  davison, mrs. thomas henry (mary e finck)  female   NaN
# 386                                  davies, mr. charles henry    male  18.0
# 412                                            hart, mr. henry    male   NaN
# 477                                    renouf, mr. peter henry    male  34.0
# 483                                   rouse, mr. richard henry    male  50.0
# 509                                   olsen, mr. henry margido    male  28.0
# 595                                    chapman, mr. john henry    male  37.0
# 624                                hansen, mr. henry damsgaard    male  21.0
# 631                       barkworth, mr. algernon henry wilson    male  80.0
# 634                              parr, mr. william henry marsh    male   NaN
# 646                                  harper, mr. henry sleeper    male  48.0
# 661                              frauenthal, dr. henry william    male  50.0
# 673                                mitchell, mr. henry michael    male  70.0
# 696                                 chapman, mr. charles henry    male  52.0
# 706             morley, mr. henry samuel ("mr henry marshall")    male  39.0
# 723                               gillespie, mr. william henry    male  34.0
# 724                                    hodges, mr. henry price    male  50.0
# 727                renouf, mrs. peter henry (lillian jefferys)  female  30.0
# 885                                     sutehall, mr. henry jr    male  25.0
#
#              SibSp  Parch           Ticket      Fare Cabin Embarked  \
# PassengerId
# 5                0      0           373450    8.0500   NaN        S
# 13               0      0        A/5. 2151    8.0500   NaN        S
# 53               1      0         PC 17572   76.7292   D33        C
# 63               1      0            36973   83.4750   C83        S
# 160              8      2         CA. 2343   69.5500   NaN        S
# 177              3      1             4133   25.4667   NaN        S
# 210              0      0           112277   31.0000   A31        C
# 213              0      0        A/5 21174    7.2500   NaN        S
# 223              0      0            21440    8.0500   NaN        S
# 228              0      0        A/5 21173    7.2500   NaN        S
# 231              1      0            36973   83.4750   C83        S
# 240              0      0       SCO/W 1585   12.2750   NaN        S
# 265              0      0           382649    7.7500   NaN        Q
# 272              0      0             LINE    0.0000   NaN        S
# 335              1      0         PC 17611  133.6500   NaN        S
# 348              1      0           386525   16.1000   NaN        S
# 386              0      0     S.O.C. 14879   73.5000   NaN        S
# 412              0      0           394140    6.8583   NaN        Q
# 477              1      0            31027   21.0000   NaN        S
# 483              0      0         A/5 3594    8.0500   NaN        S
# 509              0      0           C 4001   22.5250   NaN        S
# 595              1      0      SC/AH 29037   26.0000   NaN        S
# 624              0      0           350029    7.8542   NaN        S
# 631              0      0            27042   30.0000   A23        S
# 634              0      0           112052    0.0000   NaN        S
# 646              1      0         PC 17572   76.7292   D33        C
# 661              2      0         PC 17611  133.6500   NaN        S
# 673              0      0       C.A. 24580   10.5000   NaN        S
# 696              0      0           248731   13.5000   NaN        S
# 706              0      0           250655   26.0000   NaN        S
# 723              0      0            12233   13.0000   NaN        S
# 724              0      0           250643   13.0000   NaN        S
# 727              3      0            31027   21.0000   NaN        S
# 885              0      0  SOTON/OQ 392076    7.0500   NaN        S
#
#                  Surname
# PassengerId
# 5                  allen
# 13           saundercock
# 53                harper
# 63                harris
# 160                 sage
# 177              lefebre
# 210                blank
# 213               perkin
# 223                green
# 228               lovell
# 231               harris
# 240                 hunt
# 265                henry
# 272            tornquist
# 335           frauenthal
# 348              davison
# 386               davies
# 412                 hart
# 477               renouf
# 483                rouse
# 509                olsen
# 595              chapman
# 624               hansen
# 631            barkworth
# 634                 parr
# 646               harper
# 661           frauenthal
# 673             mitchell
# 696              chapman
# 706               morley
# 723            gillespie
# 724               hodges
# 727               renouf
# 885             sutehall

# %%
# select Name of the passenger with the longest Name
titanic.loc[titanic["Name"].str.len().idxmax(), "Name"]
# idxmax() gets the index label for which the length is the largest
# Out:
# 'penasco y castellana, mrs. victor de satode (maria josefa perez de soto y vallejo)'

# %%
# replace values of "male" by "M" and values of "female" by "F" and add it as a new column
# replace method requires a dictionary to define the mapping {from: to}
titanic["Gender"] = titanic["Sex"].replace({"male": "M", "female": "F"})

# %%
titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      braund, mr. owen harris    male  22.0
# 2            cumings, mrs. john bradley (florence briggs th...  female  38.0
# 3                                       heikkinen, miss. laina  female  26.0
# 4                 futrelle, mrs. jacques heath (lily may peel)  female  35.0
# 5                                     allen, mr. william henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
#
#                Surname Gender
# PassengerId
# 1               braund      M
# 2              cumings      F
# 3            heikkinen      F
# 4             futrelle      F
# 5                allen      M
